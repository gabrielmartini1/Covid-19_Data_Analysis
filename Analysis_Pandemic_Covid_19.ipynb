# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmartini1/Covid-19_Data_Analysis/blob/main/Analysis_Pandemic_Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# ## **Panorama do Covid-19 no Mundo, Brasil**
#
# ---
# <p>by Gabriel Martini - Data Scientist</p>
# <p>March 16, 2023</p>
#
# <p align="right"><font size="1.5"><a href="https://br.freepik.com/vetores-gratis/covid-19-projeto-de-surto-de-coronavirus-com-celula-de-virus-em-vista-microscopica-sobre-fundo-azul-modelo-de-ilustracao-no-tema-epidemico-de-sars-perigoso-para-banner-ou-panfleto-promocional_7367993.htm?query=corona%20virus#from_view=detail_alsolike">Imagem de articular</a> no Freepik</p></font>
#
# <img alt="Coronavirus" width="100%" src="https://img.freepik.com/vetores-gratis/covid-19-projeto-de-surto-de-coronavirus-com-celula-de-virus-em-vista-microscopica-sobre-fundo-azul-modelo-de-ilustracao-no-tema-epidemico-de-sars-perigoso-para-banner-ou-panfleto-promocional_1314-2644.jpg?size=626&ext=jpg&ga=GA1.2.196841433.1679488979&semt=sph">

# %% [markdown]
# <br>
#
# ##**1. Introdução**
#
# <p align="justify">O Covid-19, é uma doença infecciosa causada pelo coronavírus denominado SARS-CoV-2, que foi identificado pela primeira vez em dezembro de 2019 em Wuhan, na região central da China.</p>
#
# <p align="justify">Em 30 de janeiro de 2020, a Organização Mundial da Saúde (OMS) declarou que a epidemia da Covid-19 constituía uma Emergência de Saúde Pública de Importância Internacional, e, em 11 de março de 2020, uma pandemia.</p>
#
# <p align="justify">O coronavírus pode ser transmitido por contato direto com uma pessoa infectada (durante um aperto de mão seguido do toque nos olhos, nariz ou boca), por meio da exposição a gotículas respiratórias expelidas, contendo o vírus, por uma pessoa infectada quando ela tosse ou espirra (com menos de 1 metro de distância da outra pessoa) e a transmissão por aerossol, que são as gotículas respiratórias menores, contendo o vírus e que podem permanecer suspensas no ar, serem carregadas por distâncias maiores que 1 metro e por períodos mais longos.</p>
#
# <p align="justify">Os sintomas do Covid-19 podem variar de leves a graves e incluem febre, tosse seca, fadiga, falta de ar, dor de cabeça, dor de garganta, perda de olfato ou paladar, entre outros. Algumas pessoas infectadas podem não apresentar sintomas, mas ainda assim serem capazes de transmitir o vírus para outras pessoas.</p>
#
# <p align="justify">Embora as vacinas tenham sido desenvolvidas e a distribuição tenha começado em vários países, o Covid-19 ainda apresenta uma ameaça significativa à saude pública global e continua a desafiar governos e sistemas de saúde.</p>
#
# <p align="justify">Os esforços para conter a propagação do vírus, desde o início da crise sanitária, incluem medidas como o distanciamento social, uso de máscaras, higiene adequada das mãos, quarentenas e, em último caso, lockdowns.</p>
#
# <p align="justify">O primeiro caso de Covid-19 no Brasil, foi confirmado em 26 de fevereiro de 2020. Tratava-se de um homem idoso, residente de São Paulo, que havia retornado de uma viagem internacional da Itália. O primeiro óbito ocorreu em 17 de março de 2020.</p>
#
# <p align="justify">No Brasil, o Covid-19 se espalhou rapidamente desde o início de 2020 e causou milhões de casos e mortalidades. O país enfrentou grandes desafios para conter a propagação do vírus, devido a uma série de fatores, incluindo desigualdades socioeconômicas, falta de recursos de saúde adequados em algumas regiões, atrasos na implementação de medidas preventivas e falta de coordenação em nível nacional.</p>
#
# <p align="justify">Desde o início da pandemia, houve uma grande quantidade de dados sobre o Covid-19 sendo coletados e divulgados por governos, organizações internacionais, instituições de pesquisa, hospitais, laboratórios e outras fontes. Esses dados incluem o número de casos confirmados, mortes, recuperados, hospitalizados, quantidade de testes realizados, quantidade de vacinas administradas, entre outros.</p>
#
# <p align="justify">Entretanto, houve uma série de questões e controvérsias relacionadas à coleta, análise e divulgação de dados sobre o Covid-19 no Brasil. Algumas das principais questões incluem:</p>
#
# <p align="justify"> a) Falta de padronização: os dados sobre o Covid-19 são coletados por diversas agências governamentais e organizações em todo o país, e nem sempre existe uma padronização clara na forma como esses dados são coletados e relatados. Isso pode levar a inconsistências e discrepâncias nos dados.</p>
#
# <p align="justify"> b) Subnotificação: há suspeitas de que os números oficiais de casos e mortes por Covid-19 no Brasil possam estar subestimados devido a uma série de fatores, incluindo falta de testagem adequada e subnotificação por parte das autoridades.</p>
#
# <p align="justify"> c) Dificuldades na coleta de dados: o Brasil é um país enorme e diverso, com muitas áreas remotas e pobres que podem ter dificuldades em fornecer dados precisos e atualizados sobre a situação do Covid-19.</p>
#
# <p align="justify"> d) Disputas políticas: a pandemia do Covid-19 se tornou uma questão altamente politizada no Brasil, e as autoridades em diferentes níveis do governo muitas vezes têm interesses conflitantes ou agendas políticas que podem afetar a coleta e divulgação de dados.</p>
#
# <p align="justify">Os cientistas de dados têm um papel fundamental na análise e interpretação dos dados do Covid-19. Eles podem usar técnicas de análise de dados avançadas, como aprendizado de máquina e mineração de dados, para ajudar a entender a propagação da doença e entender seu impacto na saúde e segurança pública, e também na economia global.</p>
#
# <p align="justify">Embora os dados do Covid-19 sejam uma ferramenta importante para combater a pandemia, é importante lembrar que eles nem sempre são precisos ou completos. Existem muitos fatores que podem afetar a coleta e a precisão dos dados, incluindo a disponibilidade de testes, a qualidade dos sistemas de relatórios de saúde e a falta de transparência em alguns países.</p>
#
# <p align="justify">No entanto, os dados do Covid-19 continuam a ser uma ferramenta essencial para entender e combater a pandemia em todo o mundo. A análise e interpretação desses dados podem ajudar a identificar tendências, riscos e desafios e orientar as decisões de políticas de saúde pública em todos os níveis.</p>

# %% [markdown]
# ###**1.1 Objetivos Gerais**
#
# * Identificar tendências na disseminação do vírus em diferentes regiões geográficas e grupos demográficos;
#
# * Identificar quais países tiveram o maior número de casos, mortalidade, testes realizados e vacinações;
#
# * Analisar a relação entre a taxa de casos e a taxa de mortalidade em diferentes países;
#
# * Investigar a relação entre as políticas de mitigação e as taxas de casos e mortes em diferentes países;
#
# <br>

# %% [markdown]
# <br>
#
# ## **2. Obtenção dos Dados**
#
# <p align="justify">Para realizarmos esta análise exploratória sobre o Panorama do Covid-19, vamos utilizar o conjunto de dados denominado "Owid-Covid-19 Data" do projeto Our World Data, que apresenta informações sobre a pandemia de Covid-19 em todo o mundo.</p>
#
# <p align="justify">O projeto Our World in Data, pertence à instituição inglesa Global Change Data. Ele busca apresentar pesquisas e dados sobre os principais problemas globais e suas tendências ao longo do tempo. O conjunto de dados é atualizado diariamente e contém informações sobre casos confirmados, mortes, testes realizados e vacinações, entre outras variáveis. As informações são coletadas de fontes oficiais, como governos e agências internacionais de saúde, e estão disponíveis publicamente para download e uso em pesquisas, através do repositório GitHub (https://github.com/owid/covid-19-data/tree/master/public/data).</p>
#
# <p align="justify">Através da mineração de dados do dataset "Owid-Covid-19 Data", será possível extraírmos alguns insights sobre o panorama do Covid-19, tais como: (1) qual é a previsibilidade sobre a disseminação do vírus; (2) identificar padrões e tendências da doença ao longo do tempo; (3) comparar os números da doença entre diferentes países e regiões; (4) avaliar a eficácia de diferentes vacinas, entre outros.</p>

# %%
# Importar as bibliotecas para o projeto
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# Usar a função skew() do módulo scipy.stats para calcular o coeficiente de assimetria
from scipy.stats import skew

# instalar wordcloud
# !pip install wordcloud -q

from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# instalar fancyimpute
# !pip install fancyimpute -q
from fancyimpute import IterativeImputer

# instalar imputation
# !pip install impyute -q
from impyute.imputation.cs import mice

# %%
# Carregar o dataset owid-covid-data.csv (by Our World in Data)
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %% [markdown]
# <br>
#
# ## **3. Análise Exploratória dos Dados - Covid-19 no Mundo**
#
# <p align="justify">A etapa de análise exploratória de dados é uma fase muito importante dentro do escopo do projeto. Através de diversas técnicas para examinar e entender a estrutura dos dados, podemos identificar problemas e anomalias, e obter insights preliminares que podem orientar a seleção de variáveis, modelos e hipóteses a serem testadas.</p>
#
# <p align="justify">Das informações contidas no arquivo "owid-covid-data.csv", sobre a pandemia de Covid-19 em diversos países desde o início de 2020, algumas das análises que serão realizadas incluem:</p>
#
# ><p align="justify">Visualização e sumarização das principais estatísticas descritivas das variáveis do conjunto de dados, como média, mediana, desvio padrão, mínimo, máximo e quartis;</p>
#
# ><p align="justify">Análise de distribuições de frequência e histogramas das variáveis quantitativas, para identificar possíveis outliers ou valores extremos que possam distorcer a análise;</p>
#
# ><p align="justify">Criação de gráficos e visualizações para explorar possíveis correlações entre as variáveis, como a evolução dos casos confirmados e óbitos em diferentes países ao longo do tempo;</p>
#
# ><p align="justify">Identificação de possíveis problemas de integridade dos dados, como valores ausentes, inconsistências ou erros de digitação;</p>
#
# ><p align="justify">Análise de tendências temporais e sazonalidades nos dados, por exemplo, para verificar se o número de casos ou óbitos aumentou ou diminuiu em determinados períodos;</p>
#
# ><p align="justify">Identificação de padrões geográficos e demográficos nas variáveis, como diferenças no impacto da pandemia entre países com diferentes níveis de desenvolvimento ou densidade populacional;</p>
#
# ><p align="justify">Essas análises iniciais podem ajudar a orientar a seleção de modelos e hipóteses mais complexas em etapas posteriores do projeto, e contribuir para a elaboração de políticas públicas e estratégias de prevenção e controle da pandemia.</p>
#
# <br>
#
# ###**3.1 Nomenclatura das variáveis**
# <br>
#
# **Casos Confirmados (*Confirmed cases*)**
# * `total_cases` - Total de casos confirmados de COVID-19.
# * `new_cases` - Novos casos confirmados.
# * `new_cases_smoothed` - Novos casos confirmados (com média móvel de 7 dias).
# * `total_cases_per_million` - Total de casos confirmados por 1 milhão de pessoas.
# * `new_cases_per_million` - Novos casos por 1 milhão de pessoas.
# * `new_cases_smoothed_per_million` - Novos casos confirmados (com média móvel de 7 dias) por 1 milhão de pessoas.
#
# <br>
#
# **Mortes confirmadas (*Confirmed deaths*)**
# * `total_deaths` - Total de mortes atribuídas à COVID-19.
# * `new_deaths` - Novas mortes atribuídas à COVID-19.
# * `new_deaths_smoothed` - Novas mortes atribuídas à COVID-19 (com média móvel de 7 dias).
# * `total_deaths_per_million` - Total de mortes por 1 milhão de pessoas.
# * `new_deaths_per_million` - Novas mortes atribuídas à COVID-19 por 1 milhão de pessoas.
# * `new_deaths_smoothed_per_million` - Novas mortes atribuídas à COVID-19 (com média móvel de 7 dias) por 1 milhão de pessoas.
#
# <br>
#
# **Excesso de mortalidade (*Excess mortality*)**
# * `excess_mortality` - Diferença percentual entre o número relatado de mortes semanais ou mensais em 2020/2021 e o número projetado de mortes para o mesmo período com base nos anos anteriores.
# * `excess_mortality_cumulative` - Diferença percentual entre o número acumulado de mortes desde 1º de janeiro de 2020 e as mortes projetadas cumulativas para o mesmo período com base nos anos anteriores.
# * `excess_mortality_cumulative_absolute` - Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base nos anos anteriores.
# * `excess_mortality_cumulative_per_million` - Diferença cumulativa entre o número relatado de mortes desde 1º de janeiro de 2020 e o número projetado de mortes para o mesmo período com base nos anos anteriores, por milhão de pessoas.
#
# <br>
#
# **Hospital e UTI (*Hospital & ICU*)**
# * `icu_patients` - Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia.
# * `icu_patients_per_million` - Número de pacientes com COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1 milhão de pessoas.
# * `hosp_patients` - Número de pacientes com COVID-19 internados em um determinado dia.
# * `hosp_patients_per_million` - Número de pacientes com COVID-19 hospitalizados em um determinado dia por 1 milhão de pessoas.
# * `weekly_icu_admissions` - Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana.
# * `weekly_icu_admissions_per_million` - Número de pacientes com COVID-19 recém-admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana por 1 milhão de pessoas.
# * `weekly_hosp_admissions` - Número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana.
# * `weekly_hosp_admissions_per_million` - Número de pacientes com COVID-19 recém-admitidos em hospitais em uma determinada semana por 1 milhão de pessoas.
#
# <br>
#
# **Respostas de políticas (*Policy responses*)**
# * `stringency_index` - Índice de Severidade de Resposta do Governo: medida composta com base em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibições de viagens, reescalonados para um valor de 0 a 100, onde o valor de 100 é a resposta mais rigorosa.
#
# <br>
#
# **Taxa de reprodução (*Reproduction rate*)**
# * `reproduction_rate` - Estimativa em tempo real da taxa efetiva de reprodução (R) do COVID-19.
#
# <br>
#
# **Testes e positividade (*Tests & positivity*)**
# * `total_tests` - Total de testes para COVID-19
# * `new_tests` - Novos testes para COVID-19 (calculados apenas para dias consecutivos)
# * `total_tests_per_thousand` - Total de testes para COVID-19 por 1.000 pessoas.
# * `new_tests_per_thousand` - Novos testes para COVID-19 por 1.000 pessoas.
# * `new_tests_smoothed` - Novos testes para COVID-19 (com média móvel de 7 dias).
# * `new_tests_smoothed_per_thousand` - Novos testes para COVID-19 (com média móvel de 7 dias) por 1.000 pessoas.
# * `positive_rate` - A parcela de testes positivos para COVID-19, dada como uma média contínua de 7 dias.
# * `tests_per_case` - Testes realizados por novo caso confirmado de COVID-19, dados como uma média contínua de 7 dias.
# * `tests_units` - Unidades usadas pelo local para relatar seus dados de teste.
#
# <br>
#
# **Vacinações (*Vaccinations*)**
# * `total_vaccinations` - Número total de doses de vacinação contra COVID-19 administradas.
# * `people_vaccinated` - Número total de pessoas que receberam pelo menos uma dose de vacina.
# * `people_fully_vaccinated` - Número total de pessoas que receberam todas as doses de vacinação.
# * `total_boosters` - Número total de doses de reforço da vacinação administradas contra a COVID-19.
# * `new_vaccinations` - Novas doses de vacinação administradas contra a COVID-19.
# * `new_vaccinations_smoothed` - Novas doses de vacinação COVID-19 administradas (com média móvel de 7 dias).
# * `total_vaccinations_per_hundred` - Número total de doses de vacinação contra COVID-19 administradas por 100 pessoas na população total.
# * `people_vaccinated_per_hundred` - Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total.
# * `people_fully_vaccinated_per_hundred` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo inicial de vacinação por 100 pessoas na população total.
# * `total_boosters_per_hundred` - Número total de doses de reforço da vacinação contra COVID-19 administradas por 100 pessoas na população total.
# * `new_vaccinations_smoothed_per_million` - Novas doses de vacinação contra COVID-19 administradas (com média móvel de 7 dias) por 1 milhão de pessoas na população total.
# * `new_people_vaccinated_smoothed` - Número diário de pessoas que receberam a primeira dose da vacina (com média móvel de 7 dias).
# * `new_people_vaccinated_smoothed_per_hundred` - Número diário de pessoas que receberam a primeira dose da vacina (com média móvel de 7 dias) por 100 pessoas na população total.
#
# <br>
#
# **Outros atributos (*Others*)**
# * `iso_code` - ISO 3166-1 alfa-3 – códigos de país com três letras.
# * `continent` - Localização geográfica - por continente.
# * `location` - Localização geográfica.
# * `date` - Data de observação.
# * `population` - População.
# * `population_density` - Número de pessoas dividido por área de terra, medida em quilômetros quadrados.
# * `median_age` - Idade média da população, projeção da ONU para 2020.
# * `aged_65_older` - Parcela da população com 65 anos ou mais.
# * `aged_70_older` - Proporção da população com 70 anos.
# * `gdp_per_capita` - PIB - Produto Interno Bruto (em dólares).
# * `extreme_poverty` - Parcela da população que vive em extrema pobreza.
# * `cardiovasc_death_rate` - Taxa de mortalidade por doenças cardiovasculares em 2017 (número anual de mortes por 100.000 pessoas).
# * `diabetes_prevalence` - Prevalência de diabetes (% da população de 20 a 79 anos) em 2017.
# * `female_smokers` - Proporção de mulheres que fumam.
# * `male_smokers` - Parcela de homens que fumam.
# * `handwashing_facilities` - Parcela da população com instalações básicas de lavagem das mãos.
# * `hospital_beds_per_thousand` - Camas hospitalares por 1.000 pessoas.
# * `life_expectancy` - Expectativa de vida em 2019.
# * `human_development_index` - Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano – uma vida longa e saudável, conhecimento e um padrão de vida decente, baseados em 2019.
# <br><br>

# %% [markdown]
# ###**3.2 Conhecendo o tamanho e o formato do dataset**
#
#
# <p align="justify">Uma primeira impressão sobre o dataset "owid-covid-data.csv", é visualizarmos o início das primeiras entradas de dados, conforme o código e output abaixo:</p>

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# <br>
#
# Podemos também visualizar o término das entradas de dados, conforme o código e output abaixo: <br>

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 299023      ZWE    Africa  Zimbabwe  2023-03-25     264508.0        4.0
# 299024      ZWE    Africa  Zimbabwe  2023-03-26     264509.0        1.0
# 299025      ZWE    Africa  Zimbabwe  2023-03-27     264511.0        2.0
# 299026      ZWE    Africa  Zimbabwe  2023-03-28     264511.0        0.0
# 299027      ZWE    Africa  Zimbabwe  2023-03-29     264511.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 299023               9.571        5679.0         0.0                0.286
# 299024               8.714        5679.0         0.0                0.143
# 299025               7.857        5679.0         0.0                0.143
# 299026               5.857        5679.0         0.0                0.143
# 299027               5.143        5679.0         0.0                0.000
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# <br>
#
# Em seguida, vamos conhecer o tamanho do nosso DataFrame. Observe que o arquivo "owid-covid-data.csv" contém um total de 299.028 linhas e 67 colunas, conforme demonstrado abaixo: <br>

# %%
df.shape
# Out:
# (299028, 67)

# %% [markdown]
# ###**3.3 Conhecendo os tipos das variáveis**
#
# <p align="justify">Usando o comando "pd.set_option", vamos formatar o console do Python para permitir a visualização da lista completa de variáveis do dataset.<br>

# %%
# Usando o comando 'pd.set_option' para aumentar a quantidade de linhas exibidas no console do Python
pd.set_option('display.max_rows', None)

# Visualizar os tipos de variáveis do dataset
df.dtypes
# Out:
# iso_code                                       object
# continent                                      object
# location                                       object
# date                                           object
# total_cases                                   float64
# new_cases                                     float64
# new_cases_smoothed                            float64
# total_deaths                                  float64
# new_deaths                                    float64
# new_deaths_smoothed                           float64
# total_cases_per_million                       float64
# new_cases_per_million                         float64
# new_cases_smoothed_per_million                float64
# total_deaths_per_million                      float64
# new_deaths_per_million                        float64
# new_deaths_smoothed_per_million               float64
# reproduction_rate                             float64
# ...

# %% [markdown]
# <br>
#
# <p align="justify"> Foi possível observamos que apenas os atributos 'iso_code', 'continent', 'location', 'date' e 'total_vaccinations' são variáveis do tipo 'object', enquanto que o restante são variáveis do tipo 'float64'.</p>
#
# <p align="justify"> Atributos do tipo 'object' são variáveis categóricas, ou seja, representam informações que podem ser classificadas em um conjunto finito de categorias ou classes. Essas variáveis são tipicamente representadas por strings de texto, embora possam incluir outros tipos de dados, como datas, códigos alfanuméricos, entre outros.</p>
#
# <p align="justify"> Por exemplo, no conjunto de dados do Covid-19, a coluna 'location' é uma variável categórica que indica o país ou região geográfica em que os dados foram registrados. Outros exemplos de variáveis categóricas em conjuntos de dados podem incluir gênero, estado civil, nível educacional, tipo de produto, entre outros.</p>
#
# <p align="justify">Já os atributos do tipo 'float64' são variáveis numéricas que representam números com casas decimais em Python e em outras linguagens de programação. Essas variáveis representam quantidades numéricas contínuas ou discretas, como preços, quantidades, medidas, etc.</p>
#
# <p align="justify">Conhecer o tipo de cada variável presente no dataset é muito importante, porque pode afetar as análises de dados e as técnicas estatísticas aplicadas.</p>

# %% [markdown]
# ###**3.4 Identificando a porcentagem de valores ausentes das colunas**
#
# <p align="justify">Através do comando "isnull( ).sum( )", vamos levantar o total de valores ausentes ("missing values") em cada coluna do dataset. Vale lembrar, que a presença de valores ausentes pode afetar a qualidade dos dados e, consequentemente, a confiabilidade das análises e conclusões que podem ser obtidas a partir deles.</p>
#
# <p align="justify">Se muitos valores estão faltando em uma coluna, isso pode indicar que a fonte de dados pode ser incompleta ou que ocorreram erros na coleta ou processamento dos dados.</p>
# <br>
#
# ###**3.4.1 Preparação dos dados**
# <p align="justify">Muitas técnicas de análise de dados requerem que não haja valores ausentes nos dados, ou que esses valores sejam tratados de alguma forma antes da análise. Portanto, é importante conhecer a extensão dos valores ausentes em cada coluna para que possamos escolher a melhor forma de tratá-los (por exemplo, preencher com valores médios, excluir os registros, etc).</p>
#
# <p align="justify">Planejamento da análise: a presença de valores ausentes pode afetar o planejamento da análise e a escolha das técnicas estatísticas que podem ser aplicadas. Por exemplo, se muitos valores estão faltando em uma coluna, isso pode limitar as opções de técnicas estatísticas que podem ser aplicadas nessa coluna.</p>
#
# <p align="justify">Comunicação dos resultados: ao relatar os resultados de uma análise de dados, é importante incluir informações sobre os valores ausentes e como eles foram tratados. Isso pode ajudar os leitores a entender melhor as limitações e os pontos fortes dos resultados apresentados.</p>
#
# <p align="justify">Em resumo, levantar o total de valores ausentes é um primeiro passo importante na análise de dados, que pode ajudar a garantir a qualidade dos dados e a escolha adequada de técnicas de análise.</p>
# <br>

# %%
# Visualizar o total de dados ausentes
df.isnull().sum()
# Out:
# iso_code                                           0
# continent                                      14193
# location                                           0
# date                                               0
# total_cases                                    35674
# new_cases                                       8424
# new_cases_smoothed                              9688
# total_deaths                                   55799
# new_deaths                                      8342
# new_deaths_smoothed                             9572
# total_cases_per_million                        35674
# new_cases_per_million                           8424
# new_cases_smoothed_per_million                  9688
# total_deaths_per_million                       55799
# new_deaths_per_million                          8342
# new_deaths_smoothed_per_million                 9572
# reproduction_rate                             114211
# icu_patients                                  264480
# ...

# %%
# listar as variáveis com seus valores ausentes em ordem decrescente
(df.isnull().sum() / df.shape[0]*100).sort_values(ascending=False)
# Out:
# weekly_icu_admissions                         96.991252
# weekly_icu_admissions_per_million             96.991252
# excess_mortality_cumulative_absolute          96.557179
# excess_mortality_cumulative_per_million       96.557179
# excess_mortality_cumulative                   96.557179
# excess_mortality                              96.557179
# weekly_hosp_admissions_per_million            92.934107
# weekly_hosp_admissions                        92.934107
# icu_patients_per_million                      88.446567
# icu_patients                                  88.446567
# hosp_patients_per_million                     88.328518
# hosp_patients                                 88.328518
# total_boosters                                85.798654
# total_boosters_per_hundred                    85.798654
# new_vaccinations                              79.635686
# people_fully_vaccinated                       77.168359
# people_fully_vaccinated_per_hundred           77.168359
# ...

# %% [markdown]
# <br>
#
# <p align="justify">Ao executar essa linha de código, obtemos uma lista ordenada em ordem decrescente de porcentagem de valores nulos em cada coluna. Isso nos permite identificar quais colunas possuem uma quantidade significativa de valores ausentes e, portanto, podem requerer um tratamento especial durante a análise de dados.</p>
#
# <p align="justify">Em geral, podemos observar que muitas colunas têm uma quantidade significativa de valores ausentes. Algumas dessas colunas são esperadas, como as que se referem a dados de vacinação e testagem, que podem não estar disponíveis em todos os países e em todos os momentos. No entanto, outras colunas, como as que se referem a hospitalizações e admissões em UTIs, podem ser mais críticas para uma análise precisa da situação da pandemia em um determinado país.</p>
#
# <p align="justify">Além disso, há algumas colunas que possuem uma porcentagem relativamente alta de valores nulos, como aquelas relacionadas a dados socioeconômicos, como pobreza extrema, índice de desenvolvimento humano, taxas de mortalidade por doenças cardiovasculares e diabetes. Isso pode indicar que muitos países não relatam ou coletam esses dados de maneira consistente.</p>
#
# <p align="justify">Portanto, para realizar uma análise precisa dos dados, pode ser necessário excluir algumas colunas com um grande número de valores ausentes ou realizar uma imputação para preencher esses valores nulos. É importante lembrar que a qualidade e confiabilidade dos resultados de análise de dados dependem da qualidade dos dados disponíveis, e a falta de dados precisos e completos pode limitar a capacidade de análise e compreensão da situação da pandemia em todo o mundo.</p>
#
# <p align="justify">Primeiramente, vamos optar por realizar a exclusão de algumas colunas do DataFrame, que contêm alta porcentagem de dados ausentes e que não estão diretamente relacionadas aos objetivos deste estudo. Entretanto, vamos manter as colunas relacionadas a casos, mortes, testes, vacinações, políticas de mitigação e outras informações demográficas e socioeconômicas que são relevantes aos objetivos do projeto.</p>
#
# <p align="justify">Abaixo, listamos as colunas que serão excluídas do DataFrame para darmos continuidade à análise exploratória:</p><br>
#
# * `weekly_icu_admissions` (*96.98%*)<br>
# * `weekly_icu_admissions_per_million` (*96.98%*)<br>
# * `excess_mortality_cumulative_absolute` (*96.53%*)<br>
# * `excess_mortality_cumulative_per_million` (*96.53%*)<br>
# * `excess_mortality_cumulative` (*96.53%*)<br>
# * `excess_mortality` (*96.53%*)<br>
# * `weekly_hosp_admissions_per_million` (*92.93%*)<br>
# * `weekly_hosp_admissions` (*92.93%*)<br>
# * `icu_patients_per_million` (*88.50%*)<br>
# * `icu_patients` (*88.50%*)<br>
# * `hosp_patients_per_million` (*88.33%*)<br>
# * `hosp_patients` (*88.33%*)<br>
# * `total_boosters` (*85.80%*)<br>
# * `total_boosters_per_hundred` (*85.80%*)<br>
# * `tests_per_case` (*68.44%*)<br>
# * `handwashing_facilities` (*62.06%*)<br>
# * `extreme_poverty` (*50.19%*)<br>
# * `male_smokers` (*42.68%*)<br>
# * `female_smokers` (*41.89%*)<br><br>

# %%
# Criando uma cópia do dataframe
df_clean = df.copy()

# Excluindo as colunas irrelevantes aos objetivos
df_clean.drop(columns = ['weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'excess_mortality_cumulative_absolute',
                         'excess_mortality_cumulative_per_million', 'excess_mortality_cumulative', 'excess_mortality',
                         'weekly_hosp_admissions_per_million', 'weekly_hosp_admissions', 'icu_patients_per_million',
                         'icu_patients', 'hosp_patients_per_million', 'hosp_patients', 'total_boosters',
                         'total_boosters_per_hundred', 'handwashing_facilities', 'extreme_poverty',
                         'male_smokers', 'female_smokers', 'tests_per_case'], axis=1, inplace=True)

# %% [markdown]
# <br>
#
# Após a exclusão das colunas listadas acima, podemos observar que o conjunto de dados  do arquivo "owid-covid-data.csv", agora apresenta um total de 299.028 linhas e 48 colunas, conforme demonstrado abaixo: <br>

# %%
# Mostrar o tamanho do DataFrame
df_clean.shape
# Out:
# (299028, 48)

# %% [markdown]
# <br>
#
# <p align="justify">Com relação à variável categórica 'location', esperava-se encontrar apenas o respectivo nome do país como registro. Entretanto, observamos que também existem dados registrados como: 'World', 'High income', 'Upper middle income', 'Africa', 'Asia', 'Europe', 'Oceania', 'North America', 'South America', 'United Kingdom' e 'European Union', os quais estão relacionados à variável 'iso_code' e seus respectivos agrupamentos, conforme abaixo:</p>

# %%
# Verificar os dados únicos da variável 'location'
df_clean.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %% [markdown]
# <br>
#
# <p align="justify">Esse agrupamento relacionado à variável 'iso_code'será excluído, para que possamos explorar ao máximo a variável 'location' com relação ao número de casos, mortes, vacinações, entre outros.</p>

# %%
# Excluindo o agrupamento de 'location', através da variável 'iso_code'
df_clean.drop(df_clean.index[df_clean.iso_code.str.contains("OWID")].values, inplace = True)

# %% [markdown]
# <br>
#
# <p align="justify">A função "drop", removeu do DataFrame df_clean todas as linhas onde a coluna 'iso_code' contém a substring "OWID". Já a função "str.contains( )" será utilizada para verificar se a string "OWID" está presente em cada valor da coluna 'iso_code'. Se todas as entradas do tipo "OWID" foram devidamente excluídas do dataset, o output deverá exibir a quantidade total de linhas igual a zero, conforme apresentado abaixo:</p>

# %%
df_clean.loc[df_clean.iso_code.str.contains("OWID")]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# <br>
#
# <p align="justify">A seguir, vamos construir uma nuvem de palavras para a variável 'location', com o intuito de fornecer uma representação gráfica rápida e intuitiva dos termos mais relevantes presentes nesta coluna.</p>
#
# <p align="justify"> A nuvem de palavras (wordcloud) é uma técnica visual utilizada para representar a frequência das palavras em um texto, em que as palavras mais frequentes aparecem em tamanho maior e em destaque.</p>
#
# <p align="justify"> Essa técnica é frequentemente utilizada em análises exploratórias de dados e em pesquisas de opinião, em que os usuários desejam identificar rapidamente os termos mais frequentes e relevantes em um grande volume de dados não estruturados, como comentários de usuários, feedbacks de clientes, transcrições de entrevistas, entre outros.</p>

# %%
# Lista de stopwords em português
stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os"])

# Baixar a imagem da URL
url = "https://images.unsplash.com/photo-1584118624012-df056829fbd0?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1332&q=80"
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Converter a imagem em um array numpy
img_array = np.array(img)

# Concatenar as palavras da coluna location
location_concat = " ".join(df_clean['location'])

# Gerar a nuvem de palavras
wordcloud = WordCloud(stopwords=stopwords, mask=img_array,
                      background_color="white", contour_width=1,
                      contour_color="white").generate(location_concat)

# Mostrar a imagem final
fig, ax = plt.subplots(figsize=(14,7))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %% [markdown]
# <br>
#
# <p align="justify">As colunas que serão mantidas deste dataset,  ainda apresentam uma proporção significativa de seus dados ausentes. Inicialmente, optamos por utilizar a técnica de imputação da média ponderada sobre as variáveis numéricas. Entretanto, os resultados obtidos não se mostraram satisfatórios.</p>
#
# <p align="justify"> Utilizar a técnica de imputação com o modelo padrão de regressão, se mostrou uma melhor alternativa do que realizar a técnica da imputação da média ponderada para as variáveis numéricas. Já no tratamento das variáveis categóricas, optamos por preencher os registros ausentes com o valor mais frequente, a moda.</p>
# <br>

# %%
# Selecionar as colunas com valores ausentes
cols_numericas = ['total_cases', 'new_cases', 'total_deaths', 'new_deaths',
                  'total_tests', 'new_tests', 'population_density',
                  'reproduction_rate', 'population', 'gdp_per_capita',
                  'total_vaccinations', 'new_vaccinations', 'stringency_index']

cols_categoricas = df_clean.select_dtypes(include=['object']).columns

# Criar objeto do IterativeImputer com modelo padrão de regressão
imputer = IterativeImputer(random_state=0)

# Aplicar a técnica de imputação nas colunas numéricas
df_clean[cols_numericas] = imputer.fit_transform(df_clean[cols_numericas])

# Retirar valores negativos das colunas numéricas
df_clean[cols_numericas] = df_clean[cols_numericas].clip(lower=0)

# Preencher valores ausentes das colunas categóricas com o valor mais frequente (moda)
df_clean[cols_categoricas] = df_clean[cols_categoricas].fillna(df_clean[cols_categoricas].mode().iloc[0])

# Localizar valores ausentes nas colunas numéricas
cols_com_valores_ausentes = df_clean[cols_numericas].isnull().any()
print("Colunas com valores ausentes:" , cols_com_valores_ausentes[cols_com_valores_ausentes == True], '\n')

# Verificar se ainda há valores ausentes no conjunto de dados
if df_clean[cols_numericas].isna().sum().sum() == 0:
    print("Não há mais valores ausentes no conjunto de dados.")
else:
    print("Ainda há valores ausentes no conjunto de dados.")
# Out:
# Colunas com valores ausentes: Series([], dtype: bool)
#
# Não há mais valores ausentes no conjunto de dados.

# %% [markdown]
# <br>
#
# <p align="justify">O resultado indica que a imputação de valores ausentes, tanto para as variáveis numéricas quanto para as categóricas selecionadas do DataFrame, foi realizada com sucesso.</p>
#
# <p align="justify">Agora vamos lidar com os valores da coluna 'date', que é uma variável do tipo 'object', mas que precisa ser convertida para o tipo 'datetime', afim de exploramos ao máximo as suas informações por períodos.</p>
#
# <p align="justify">Quando convertemos a coluna de 'date', que é do tipo 'object' para 'datetime', ela não é mais considerada uma variável categórica e nem numérica. Em vez disso, ela se torna uma variável de data e hora, que tem suas próprias características e métodos de manipulação.</p>
#
# <p align="justify">Para realizarmos a sua conversão, vamos utilizar o método "pd.to_datetime( )" e, posteriormente, realizar operações específicas de data e hora, como agrupar dados por períodos específicos, analisar tendências e sazonalidade de dados.</p>

# %%
# converter a coluna 'date' para "datetime"
df_clean['date'] = pd.to_datetime(df['date'])

# verificar o novo formato da variável date em datetime usando o comando dtypes
print(df_clean['date'].dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# <br>
#
# ###**3.5 Confirmando a presença de outliers**
#
# <p align="justify">A detecção de outliers é uma etapa importante na análise de dados, pois pode afetar significativamente a interpretação dos resultados. Os outliers são valores extremos que estão longe do restante dos dados em um conjunto de dados. Eles podem ocorrer devido a erros de medição, erros de entrada de dados ou podem ser valores reais que são excepcionalmente altos ou baixos. A presença de outliers pode distorcer a análise de dados, afetando a média e o desvio padrão dos dados, o que pode levar a conclusões errôneas.</p>
#
# <p align="justify">O primeiro passo para detectarmos os outliers em nosso conjunto de dados é verificarmos qual é o tipo da distribuição das variáveis. Esta verificação pode ser facilmente realizada com o auxílio visual dos histogramas.</p>
#
# <p align="justify">Histogramas são uma maniera útil de visualizar a distribuição de uma variável. Elas mostram a frequência das observações para uma determinada faixa de valores, onde a largura de cada faixa é determinanda pelo parâmetro denominado 'bins', que especifica o número de faixas.</p>
#
# <p align="justify">Uma distribuição normal, por exemplo, terá um pico no centro do histograma e uma queda gradual nas extremidades. Uma distribuição assimétrica terá um pico deslocado para a esquerda ou para a direita. Um histograma com vários picos pode indicar a presença de subgrupos na população.</p>
#
# <p align="justify">Os histogramas também podem ser usados para detectar valores discrepantes (outliers) e para avaliar a forma como os dados estão distribuídos. Se houver muitos valores extremos, por exemplo, a distribuição pode ser distorcida ou desequilibrada. Se os dados tiverem uma distribuição normal, podemos usar medidas como a média e o desvio padrão para descrever a distribuição.</p>
#
# <p align="justify">Para identificar a distribuição das variáveis, iremos plotar o histograma, conforme abaixo:</p>

# %%
# Plotar o histograma das variáveis numéricas
df_clean[cols_numericas].hist(bins=12, figsize=(14, 9), color='brown');

# %% [markdown]
# <br>
#
# <p align="justify">Pela distribuição do histograma, foi possível verificar indícios da presença de outliers. As variáveis 'total_cases', 'new_cases', 'new_deaths', 'total_tests', 'new_tests', 'new_vaccinations', 'population_density' e 'population',   apresentam uma assimetria positiva ou também conhecida como assimetria para a direita, onde a cauda da curva de distribuição se estende para a direita, em direção aos valores maiores.</p>
#
# <p align="justify">Isso significa que a maioria dos valores dos dados estão concentrados na parte esquerda da curva e há alguns valores extremos maiores na parte direita. Em outras palavras, a assimetria positiva ocorre quando a média é maior que a mediana e a moda, indicando que há mais valores à direita da mediana.</p>
#
# <p align="justify">Portanto, os valores não seguem uma distribuição, e distorcem toda a representação gráfica. Para confirmar, há três maneiras rápidas que auxiliam a detecção de outliers. São elas:</p>
#
# * (1) Resumo estatístico por meio do método `describe( )`<br>
# * (2) Plotar `boxplots` para a variável
# * (3) Cálculo do coeficiente de assimetria (`Skewness`)

# %%
# Visualizar o resumo estatístico das variáveis numéricas após a imputação
df_clean[cols_numericas].describe().applymap('{:,.2f}'.format)
# Out:
#           total_cases     new_cases  total_deaths  new_deaths  \
# count      278,523.00    278,523.00    278,523.00  278,523.00
# mean     1,355,655.85      2,763.76     18,246.59       24.86
# std      5,665,929.85     39,630.99     70,135.22      146.06
# min              0.00          0.00          0.00        0.00
# 25%          6,952.00          0.00        137.00        0.00
# 50%         75,094.00         14.00      1,945.00        0.00
# 75%        793,170.00        408.00     11,462.77        4.00
# max    102,697,566.00  6,966,046.00  1,117,054.00   11,447.00
#
#             total_tests      new_tests population_density reproduction_rate  \
# count        278,523.00     278,523.00         278,523.00        278,523.00
# mean      19,934,423.39      40,136.65             415.38              0.90
# std       85,766,200.86     191,074.31           1,794.58              0.33
# min                0.00           0.00               0.00              0.00
# ...

# %% [markdown]
# <br>
#
# <p align="justify">Podemos observar que existem variáveis com valores muito altos em relação aos seus quartis, como é o caso de 'total_cases', 'total_deaths', 'total_tests', 'total_vaccinations', 'new_vaccinations' e 'population_density', cujos valores máximos são muito superiores aos seus respectivos terceiros quartis, o que pode indicar a presença de possíveis outliers.</p>
#
# <p align="justify">A média de 'total_cases' é de aproximadamente 1,3 milhões, enquanto a mediana é de 75.094, indicando uma assimetria positiva nos dados. Isso significa que a distribuição de casos totais é inclinada à direita, com alguns países tendo um número muito maior de casos do que outros.</p>
#
# <p align="justify">No contexto da pandemia de Covid-19, pode haver diferentes fatores que contribuem para a ocorrência de outliers na variável 'total_cases'. Por exemplo, alguns países podem ter uma população muito grande e, portanto, um grande número de casos registrados, enquanto outros países podem ter subnotificação de casos ou dificuldades em realizar testes em larga escala, o que pode levar a um número relativamente baixo de casos registrados.</p>
#
# <p align="justify"> A variável 'new_cases' tem mediana igual a 14.00 e 'new_deaths' tem mediana igual a zero, sugerindo que, na maioria das vezes, os países não relatam novos casos de morte diariamente. No entanto, a média de 'new_cases' é de cerca de 2.763 e a média de 'new_deaths' é de aproximadamente 24.</p>
#
# <p align="justify">A média e a mediana de 'total_tests' e 'new_tests' são significativamente diferentes, indicando que alguns países têm realizado mais testes do que outros. Isso pode ser devido a diferenças na capacidade de teste, na prevalência da doença ou em outras políticas nacionais.</p>
#
# <p align="justify">A média e a mediana de 'total_vaccinations' e 'new_vaccinations' são substancialmente diferentes, o que indica que a distribuição de vacinações também é assimétrica. Isso pode ser devido a diferenças na disponibilidade de vacinas, na velocidade de implantação da vacinação ou na aceitação da vacina entre os países.</p>
#
# <p align="justify">A variável 'population_density' tem uma média de 415 e uma mediana de 104, o que sugere que a distribuição da densidade populacional é assimétrica e inclinada à direita. Isso indica que a maioria dos países tem uma densidade populacional relativamente baixa, mas alguns países têm uma densidade populacional muito alta.</p>
#
# <p align="justify">A variável 'gdp_per_capita' tem uma média de 19.561 e uma mediana de 16.349, o que sugere uma distribuição inclinada à direita, indicando que a maioria dos países tem um PIB per capita relativamente baixo, enquanto alguns têm um PIB per capita muito alto.</p>
#
# <p align="justify">A variável 'reproduction_rate' tem uma média de 0.90 e mediana de 0.89, praticamente de mesmo valor. Esse indicador será utilizado posteriormente para calcularmos a velocidade média de disseminação do vírus.</p>
#
# <p align="justify">É importante lembrar que outliers podem distorcer a análise estatística dos dados, pois podem ter um impacto desproporcional nos cálculos de medidas de resumo, como a média e o desvio padrão. Por isso, é importante considerar a possibilidade de outliers e avaliar se eles devem ser tratados de alguma forma, como através da exclusão ou transformação desses valores, antes de realizar análises mais aprofundadas.</p>
#
# <p align="justify">Para avaliarmos se esses dados precisam ser tratados, vamos calcular o IQR Score e o Boxplots para as variáveis numéricas.</p>

# %% [markdown]
# <br>
#
# ###**3.5 Teoria do IQR Score**

# %% [markdown]
# Para definirmos o IQR Score (Intervalor Interquartil) de qualquer variável, será necessário calcular anteriormente o seu quartil 1 (Q1) e o quartil 3 (Q3).
#
# Supondo que estamos calculando o IQR da variável 'total_cases', logo temos:
#
# * Q1 = df['total_cases'].quantile(0.25)
# * Q3 = df['total_cases'].quantile(0.75)
# * Portanto, IQR = Q3 - Q1
#
# Para calcularmos o limite inferior e superior, temos:<br>
# * limite_inferior  = Q1 - 1.5 * IQR<br>
# * limite_superior = Q3 + 1.5 * IQR
#
# Com o resultado numérico do IQR Score, será possível encontrarmos os limites superior e inferior para cada variável. Sabendo que valores acima dos limites encontrados serão considerados outliers, logo poderão ser excluídos do dataset.
#
# Para trazer mais clareza ao assunto do IQR Score, vamos visualizar um exemplo do diagrama de caixa com intervalo interquartil, conforme a figura 1 abaixo:
# <br><br>
#
# <center><img alt="Intervalor_Interquartil" width="50%" src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Boxplot_vs_PDF_-_PT.svg/800px-Boxplot_vs_PDF_-_PT.svg.png"></center>.
#
#
# <p align="center">
# <font size="3">Figura 1. Diagrama de caixa (com intervalo interquartil)</font>
# </p>
#
# <p align="center">
# <font size="2">Fonte: wikipedia.org</font>
# </p>

# %% [markdown]
# <br>
#
# ###**3.6 Cálculo do IQR Score e Bloxplot**
#
# ###**3.6.1 Variável `total_cases`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'total_cases'
limite_superior = df_clean['total_cases'].quantile(0.75) + 1.5 * (df_clean['total_cases'].quantile(0.75) - df_clean['total_cases'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'total_cases'
limite_inferior = df_clean['total_cases'].quantile(0.25) - 1.5 * (df_clean['total_cases'].quantile(0.75) - df_clean['total_cases'].quantile(0.25))

print(f'Limite superior de total_cases: {limite_superior:.2f}')
print(f'Limite inferior de total_cases: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'total_cases'
df_clean.total_cases.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 1972497.00 ===>  ', (len(df_clean[df_clean.total_cases > 1972497.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_cases > 1972497.00]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 1972497.00 ======> ', (len(df_clean[df_clean.total_cases <= 1972497.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_cases <= 1972497.00]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['total_cases'])
print("Coeficiente de assimetria (skewness) =====>   {:.2f}".format(skewness))
# Out:
# Limite superior de total_cases: 1972497.00
# Limite inferior de total_cases: -1172375.00
# Acima do limite superior de 1972497.00 ===>   33349 entradas (11.97%)
# Até o limite superior de 1972497.00 ======>  245174 entradas (88.03%)
# Coeficiente de assimetria (skewness) =====>   10.37

# %% [markdown]
# <p align="justify">A partir dos cálculos de limite superior e inferior e do boxplot, podemos concluir que a variável 'total_cases' possui 33.349 registros (11,97%) de valores extremos (outliers) acima do limite superior, o que indica que alguns países apresentaram números muito elevados de casos confirmados de Covid-19.</p>
#
# <p align="justify">Isso também é confirmado pelo fato de que a média e o desvio padrão dessa variável são muito maiores do que os seus quartis.</p>
#
# <p align="justify">O coeficiente de assimetria (skewness) foi calculado como 10,37, o que indica uma forte assimetria positiva da distribuição. Além disso, o boxplot mostra uma grande quantidade de pontos acima do limite superior e poucos pontos abaixo do limite inferior.</p>
#
# <p align="justify">Dessa forma, vamos aplicar uma transformação logarítmica para reduzir a assimetria e normalizar a distribuição da variável 'total_cases'. Essa transformação pode ajudar a reduzir a influência dos valores extremos e melhorar a interpretação dos dados.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'total_cases'
print(f"Quantidade de valores iguais a zero em 'total_cases': {len(df_clean.loc[df_clean['total_cases'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'total_cases': 1282

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'total_cases'
median_total_cases = df_clean.loc[df_clean['total_cases'] > 0, 'total_cases'].median()
df_clean.loc[df_clean['total_cases'] <= 0, 'total_cases'] = median_total_cases

# Aplicar a transformação logarítmica p/ a variável 'total_cases'
df_clean['log_total_cases'] = np.log(df_clean['total_cases'])

# Plotar o boxplot da variável 'log_total_cases'
df_clean[['log_total_cases']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_total_cases')
plt.show()

print('\n')

print(f'Acima do limite superior de 1972497.00 ===>      ', (len(df_clean[df_clean.log_total_cases > 1972497.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_cases > 1972497.00]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 1972497.00 ======> ', (len(df_clean[df_clean.log_total_cases <= 1972497.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_cases <= 1972497.00]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 1972497.00 ===>       0 entradas (0.00%)
# Até o limite superior de 1972497.00 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.2 Variável `new_cases`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'new_cases'
limite_superior = df_clean['new_cases'].quantile(0.75) + 1.5 * (df_clean['new_cases'].quantile(0.75) - df_clean['new_cases'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'new_cases'
limite_inferior = df_clean['new_cases'].quantile(0.25) - 1.5 * (df_clean['new_cases'].quantile(0.75) - df_clean['new_cases'].quantile(0.25))

print(f'Limite superior de new_cases: {limite_superior:.2f}')
print(f'Limite inferior de new_cases: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'total_cases'
df_clean.new_cases.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 1020.00 =====>  ', (len(df_clean[df_clean.new_cases > 1020.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_cases > 1020.00]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 1020.00 ========> ', (len(df_clean[df_clean.new_cases <= 1020.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_cases <= 1020.00]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['new_cases'])
print("Coeficiente de assimetria (skewness) ====>  {:.2f}".format(skewness))
# Out:
# Limite superior de new_cases: 1020.00
# Limite inferior de new_cases: -612.00
# Acima do limite superior de 1020.00 =====>   48266 entradas (17.33%)
# Até o limite superior de 1020.00 ========>  230257 entradas (82.67%)
# Coeficiente de assimetria (skewness) ====>  109.99

# %% [markdown]
# <p align="justify">Com base nos códigos e outputs acima, podemos verificar que a variável 'new_cases' apresentou um alto coeficiente de assimetria (skewness) de 109,99, indicando uma distribuição extremamente assimétrica.</p>
#
# <p align="justify">Além disso, o boxplot mostra uma quantidade significativa de valores extremos acima do limite superior de 1020.00, com 17,33% das entradas acima desse limite. Isso sugere a presença de outliers na distribuição.</p>
#
# <p align="justify">É possível afirmar que a distribuição da variável 'new_cases' é extremamente assimétrica e possui um número significativo de valores extremos (outliers), o que pode dificultar análises estatísticas e visualizações precisas. Portanto, faremos a seguir uma transformação logarítmica para reduzir a assimetria e tornar a distribuição mais próxima de uma distribuição normal.</p>
#
# <p align="justify">Antes de aplicarmos a transformação logarítmica para a variável 'new_cases', vamos verificar a existência de valores iguais a zero e substituí-los pelo valor da mediana da coluna 'new_cases', conforme código e output abaixo:</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'new_cases'
print(f"Quantidade de valores iguais a zero em 'new_cases': {len(df_clean.loc[df_clean['new_cases'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'new_cases': 107796

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'new_cases'
median_new_cases = df_clean.loc[df_clean['new_cases'] > 0, 'new_cases'].median()
df_clean.loc[df_clean['new_cases'] <= 0, 'new_cases'] = median_new_cases

# Aplicar a transformação logarítmica p/ a variável 'total_cases'
df_clean['log_new_cases'] = np.log(df_clean['new_cases'])

# Plotar o boxplot da variável 'log_total_cases'
df_clean[['log_new_cases']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_new_cases')
plt.show()

print('\n')

print(f'Acima do limite superior de 1020.00 ===>      ', (len(df_clean[df_clean.log_new_cases > 1020.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_cases > 1020.00]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 1020.00 ======> ', (len(df_clean[df_clean.log_new_cases <= 1020.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_cases <= 1020.00]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 1020.00 ===>       0 entradas (0.00%)
# Até o limite superior de 1020.00 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.3 Variável `total_deaths`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'total_deaths'
limite_superior = df_clean['total_deaths'].quantile(0.75) + 1.5 * (df_clean['total_deaths'].quantile(0.75) - df_clean['total_deaths'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'total_deaths'
limite_inferior = df_clean['total_deaths'].quantile(0.25) - 1.5 * (df_clean['total_deaths'].quantile(0.75) - df_clean['total_deaths'].quantile(0.25))

print(f'Limite superior de total_deaths: {limite_superior:.2f}')
print(f'Limite inferior de total_deaths: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'total_deaths'
df_clean.total_deaths.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 28451.43 =====>  ', (len(df_clean[df_clean.total_deaths > 28451.43])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_deaths > 28451.43]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 28451.43 ========> ', (len(df_clean[df_clean.total_deaths <= 28451.43])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_deaths <= 28451.43]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['total_deaths'])
print("Coeficiente de assimetria (skewness) =====>    {:.2f}".format(skewness))
# Out:
# Limite superior de total_deaths: 28451.43
# Limite inferior de total_deaths: -16851.66
# Acima do limite superior de 28451.43 =====>   27890 entradas (10.01%)
# Até o limite superior de 28451.43 ========>  250633 entradas (89.99%)
# Coeficiente de assimetria (skewness) =====>    8.87

# %% [markdown]
# <br>
#
# <p align="justify">Com base nos resultados apresentados, podemos concluir que a variável 'total_deaths' apresenta assimetria positiva (skewness = 8.87), indicando que a maioria das observações concentra-se em valores baixos, enquanto que uma pequena parcela das observações apresenta valores muito elevados.</p>
#
# <p align="justify"> O boxplot também mostra que existem muitos valores acima do limite superior, representando 10,01% das entradas, o que sugere a presença de outliers na distribuição dos dados.</p>
#
# <p align="justify">Portanto, vamos proceder com a verificação da existência de de valores iguais a zero e posteriormente a transformação logarítmica para tornar a distribuição mais próxima da normalidade.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'total_deaths'
print(f"Quantidade de valores iguais a zero em 'total_deaths': {len(df_clean.loc[df_clean['total_deaths'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'total_deaths': 3210

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'total_deaths'
median_total_deaths = df_clean.loc[df_clean['total_deaths'] > 0, 'total_deaths'].median()
df_clean.loc[df_clean['total_deaths'] <= 0, 'total_deaths'] = median_total_deaths

# Aplicar a transformação logarítmica p/ a variável 'total_deaths'
df_clean['log_total_deaths'] = np.log(df_clean['total_deaths'])

# Plotar o boxplot da variável 'log_total_cases'
df_clean[['log_total_deaths']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_total_deaths')
plt.show()

print('\n')

print(f'Acima do limite superior de 28451.43 ===>      ', (len(df_clean[df_clean.log_total_deaths > 28451.43])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_deaths > 28451.43]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 28451.43 ======> ', (len(df_clean[df_clean.log_total_deaths <= 28451.43])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_deaths <= 28451.43]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 28451.43 ===>       0 entradas (0.00%)
# Até o limite superior de 28451.43 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.4 Variável `new_deaths`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'new_deaths'
limite_superior = df_clean['new_deaths'].quantile(0.75) + 1.5 * (df_clean['new_deaths'].quantile(0.75) - df_clean['new_deaths'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'new_deaths'
limite_inferior = df_clean['new_deaths'].quantile(0.25) - 1.5 * (df_clean['new_deaths'].quantile(0.75) - df_clean['new_deaths'].quantile(0.25))

print(f'Limite superior de new_deaths: {limite_superior:.2f}')
print(f'Limite inferior de new_deaths: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'new_deaths'
df_clean.new_deaths.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 10.00 ========>  ', (len(df_clean[df_clean.new_deaths > 10.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_deaths > 10.00]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 10.00 ===========> ', (len(df_clean[df_clean.new_deaths <= 10.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_deaths <= 10.00]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['new_deaths'])
print("Coeficiente de assimetria (skewness) =====>   {:.2f}".format(skewness))
# Out:
# Limite superior de new_deaths: 10.00
# Limite inferior de new_deaths: -6.00
# Acima do limite superior de 10.00 ========>   48971 entradas (17.58%)
# Até o limite superior de 10.00 ===========>  229552 entradas (82.42%)
# Coeficiente de assimetria (skewness) =====>   16.48

# %% [markdown]
# <br>
#
# <p align="justify">A variável 'new_deaths' apresenta uma distribuição bastante assimétrica, com um coeficiente de assimetria de 16.48 e um número considerável de entradas (17,58%) acima do limite superior de 10. Sendo assim, vamos verificar a existência de valores iguais a zero e aplicar a transformação logarítmica, conforme abaixo:</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'total_deaths'
print(f"Quantidade de valores iguais a zero em 'new_deaths': {len(df_clean.loc[df_clean['new_deaths'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'new_deaths': 173122

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'new_deaths'
median_new_deaths = df_clean.loc[df_clean['new_deaths'] > 0, 'new_deaths'].median()
df_clean.loc[df_clean['new_deaths'] <= 0, 'new_deaths'] = median_new_deaths

# Aplicar a transformação logarítmica p/ a variável 'new_deaths'
df_clean['log_new_deaths'] = np.log(df_clean['new_deaths'])

# Plotar o boxplot da variável 'log_new_deaths'
df_clean[['log_new_deaths']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_new_deaths')
plt.show()

print('\n')

print(f'Acima do limite superior de 10.00 ===>      ', (len(df_clean[df_clean.log_new_deaths > 10.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_deaths > 10.00]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 10.00 ======> ', (len(df_clean[df_clean.log_new_deaths <= 10.00])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_deaths <= 10.00]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 10.00 ===>       0 entradas (0.00%)
# Até o limite superior de 10.00 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.5 Variável `total_tests`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'total_tests'
limite_superior = df_clean['total_tests'].quantile(0.75) + 1.5 * (df_clean['total_tests'].quantile(0.75) - df_clean['total_tests'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'total_tests'
limite_inferior = df_clean['total_tests'].quantile(0.25) - 1.5 * (df_clean['total_tests'].quantile(0.75) - df_clean['total_tests'].quantile(0.25))

print(f'Limite superior de total_tests: {limite_superior:.2f}')
print(f'Limite inferior de total_tests: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'total_tests'
df_clean.total_tests.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 25358075.16 ====>   ', (len(df_clean[df_clean.total_tests > 25358075.16])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_tests > 25358075.16]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 25358075.16 =======>  ', (len(df_clean[df_clean.total_tests <= 25358075.16])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_tests <= 25358075.16]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['total_tests'])
print("Coeficiente de assimetria (skewness) =======>    {:.2f}".format(skewness))
# Out:
# Limite superior de total_tests: 25358075.16
# Limite inferior de total_tests: -15214845.10
# Acima do limite superior de 25358075.16 ====>    35586 entradas (12.78%)
# Até o limite superior de 25358075.16 =======>   242937 entradas (87.22%)
# Coeficiente de assimetria (skewness) =======>    13.29

# %% [markdown]
# <br>
#
# <p align="justify">Podemos observar que a distribuição da variável 'total_tests' é bastante assimétrica, com um coeficiente de assimetria (skewness) de 13.29, indicando uma cauda longa à direita. Entretanto, identificamos que existem 35.586 (13.29%) entradas acima do limite superior.</p>
#
# <p align="justify">A alta assimetria observada na distribuição da variável (coeficiente de assimetria = 13.29) sugere que a transformação logarítmica pode ser uma boa opção para reduzir a assimetria e tornar a distribuição mais próxima de uma distribuição normal. Além disso, a transformação logarítmica pode ajudar a lidar com a presença de valores extremos e reduzir sua influência na análise estatística.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'total_tests'
print(f"Quantidade de valores iguais a zero em 'total_tests': {len(df_clean.loc[df_clean['total_tests'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'total_tests': 111963

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'total_tests'
median_total_tests = df_clean.loc[df_clean['total_tests'] > 0, 'total_tests'].median()
df_clean.loc[df_clean['total_tests'] <= 0, 'total_tests'] = median_total_tests

# Aplicar a transformação logarítmica p/ a variável 'total_tests'
df_clean['log_total_tests'] = np.log(df_clean['total_tests'])

# Plotar o boxplot da variável 'log_total_tests'
df_clean[['log_total_tests']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_total_tests')
plt.show()

print('\n')

print(f'Acima do limite superior de 25358075.16 ===>      ', (len(df_clean[df_clean.log_total_tests > 25358075.16])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_tests > 25358075.16]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 25358075.16 ======> ', (len(df_clean[df_clean.log_total_tests <= 25358075.16])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_tests <= 25358075.16]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 25358075.16 ===>       0 entradas (0.00%)
# Até o limite superior de 25358075.16 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.6 Variável `new_tests`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'new_tests'
limite_superior = df_clean['new_tests'].quantile(0.75) + 1.5 * (df_clean['new_tests'].quantile(0.75) - df_clean['new_tests'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'new_tests'
limite_inferior = df_clean['new_tests'].quantile(0.25) - 1.5 * (df_clean['new_tests'].quantile(0.75) - df_clean['new_tests'].quantile(0.25))

print(f'Limite superior de new_tests: {limite_superior:.2f}')
print(f'Limite inferior de new_tests: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'new_tests'
df_clean.new_tests.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 52695.94 =====>  ', (len(df_clean[df_clean.new_tests > 52695.94])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_tests > 52695.94]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 52695.94 ========> ', (len(df_clean[df_clean.new_tests <= 52695.94])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_tests <= 52695.94]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'total_cases'
skewness = skew(df_clean['new_tests'])
print("Coeficiente de assimetria (skewness) =====>   {:.2f}".format(skewness))
# Out:
# Limite superior de new_tests: 52695.94
# Limite inferior de new_tests: -31617.56
# Acima do limite superior de 52695.94 =====>   39810 entradas (14.29%)
# Até o limite superior de 52695.94 ========>  238713 entradas (85.71%)
# Coeficiente de assimetria (skewness) =====>   56.01

# %% [markdown]
# <p align="justify">A variável 'new_tests' apresenta um alto coeficiente de assimetria (56.01), indicando que há uma grande assimetria à direita nos dados. Como esta variável é relevante para a análise em questão, vamos proceder com a verificação dos valores iguais a zero e a transformação para a escala logarítmica, conforme demonstrado abaixo:</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'new_tests'
print(f"Quantidade de valores iguais a zero em 'new_tests': {len(df_clean.loc[df_clean['new_tests'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'new_tests': 113143

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'new_tests'
median_new_tests = df_clean.loc[df_clean['new_tests'] > 0, 'new_tests'].median()
df_clean.loc[df_clean['new_tests'] <= 0, 'new_tests'] = median_new_tests

# Aplicar a transformação logarítmica p/ a variável 'new_tests'
df_clean['log_new_tests'] = np.log(df_clean['new_tests'])

# Plotar o boxplot da variável 'log_new_tests'
df_clean[['log_new_tests']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_new_tests')
plt.show()

print('\n')

print(f'Acima do limite superior de 52695.94 ===>      ', (len(df_clean[df_clean.log_new_tests > 52695.94])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_tests > 52695.94]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 52695.94 ======> ', (len(df_clean[df_clean.log_new_tests <= 52695.94])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_tests <= 52695.94]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 52695.94 ===>       0 entradas (0.00%)
# Até o limite superior de 52695.94 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.7 Variável `total_vaccinations`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'total_vaccinations'
limite_superior = df_clean['total_vaccinations'].quantile(0.75) + 1.5 * (df_clean['total_vaccinations'].quantile(0.75) - df_clean['total_vaccinations'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'total_vaccinations'
limite_inferior = df_clean['total_vaccinations'].quantile(0.25) - 1.5 * (df_clean['total_vaccinations'].quantile(0.75) - df_clean['total_vaccinations'].quantile(0.25))

print(f'Limite superior de total_vaccinations: {limite_superior:.2f}')
print(f'Limite inferior de total_vaccinations: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'total_vaccinations'
df_clean.total_vaccinations.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 48218138.25 ===>   ', (len(df_clean[df_clean.total_vaccinations > 48218138.25])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_vaccinations > 48218138.25]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 48218138.25 ======>  ', (len(df_clean[df_clean.total_vaccinations <= 48218138.25])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.total_vaccinations <= 48218138.25]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'tests_per_case'
skewness = skew(df_clean['total_vaccinations'])
print("Coeficiente de assimetria (skewness) ======>    {:.2f}".format(skewness))
# Out:
# Limite superior de total_vaccinations: 48218138.25
# Limite inferior de total_vaccinations: -28930882.95
# Acima do limite superior de 48218138.25 ===>    34022 entradas (12.22%)
# Até o limite superior de 48218138.25 ======>   244501 entradas (87.78%)
# Coeficiente de assimetria (skewness) ======>    12.31

# %% [markdown]
# <br>
#
# <p align="justify">O resultado obtido indica que existem 34.022 valores acima do limite superior para a variável 'total_vaccinations'. Temos um coeficiente de assimetria de 12.31, isso indica uma distribuição altamente assimétrica à direita, ou seja, existem muitos valores extremamente altos puxando a média para esse lado. Isso sugere que a maioria dos países têm baixas quantidades de vacinação e que poucos países possuem altas quantidades de vacinação.</p>
#
# <p align="justify">Utilizaremos a transformação logarítmica para reduzir a assimetria da distribuição e, assim, melhorar a análise. Abaixo, a verificação dos valores iguais a zero.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'total_vaccinations'
print(f"Quantidade de valores iguais a zero em 'total_vaccinations': {len(df_clean.loc[df_clean['total_vaccinations'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'total_vaccinations': 99334

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'total_vaccinations'
median_total_vaccinations = df_clean.loc[df_clean['total_vaccinations'] > 0, 'total_vaccinations'].median()
df_clean.loc[df_clean['total_vaccinations'] <= 0, 'total_vaccinations'] = median_total_vaccinations

# Aplicar a transformação logarítmica p/ a variável 'total_vaccinations'
df_clean['log_total_vaccinations'] = np.log(df_clean['total_vaccinations'])

# Plotar o boxplot da variável 'log_total_vaccinations'
df_clean[['log_total_vaccinations']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_total_vaccinations')
plt.show()

print('\n')

print(f'Acima do limite superior de 48218138.25 ===>      ', (len(df_clean[df_clean.log_total_vaccinations > 48218138.25])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_vaccinations > 48218138.25]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 48218138.25 ======> ', (len(df_clean[df_clean.log_total_vaccinations <= 48218138.25])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_total_vaccinations <= 48218138.25]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 48218138.25 ===>       0 entradas (0.00%)
# Até o limite superior de 48218138.25 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.8 Variável `new_vaccinations`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'new_vaccinations'
limite_superior = df_clean['new_vaccinations'].quantile(0.75) + 1.5 * (df_clean['new_vaccinations'].quantile(0.75) - df_clean['new_vaccinations'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'new_vaccinations'
limite_inferior = df_clean['new_vaccinations'].quantile(0.25) - 1.5 * (df_clean['new_vaccinations'].quantile(0.75) - df_clean['new_vaccinations'].quantile(0.25))

print(f'Limite superior de new_vaccinations: {limite_superior:.2f}')
print(f'Limite inferior de new_vaccinations: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'new_vaccinations'
df_clean.new_vaccinations.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 193100.24 ===>   ', (len(df_clean[df_clean.new_vaccinations > 193100.24])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_vaccinations > 193100.24]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 193100.24 ======>  ', (len(df_clean[df_clean.new_vaccinations <= 193100.24])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.new_vaccinations <= 193100.24]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'tests_per_case'
skewness = skew(df_clean['new_vaccinations'])
print("Coeficiente de assimetria (skewness) ====>    {:.2f}".format(skewness))
# Out:
# Limite superior de new_vaccinations: 193100.24
# Limite inferior de new_vaccinations: -115860.15
# Acima do limite superior de 193100.24 ===>    28976 entradas (10.40%)
# Até o limite superior de 193100.24 ======>   249547 entradas (89.60%)
# Coeficiente de assimetria (skewness) ====>    17.52

# %% [markdown]
# <br>
#
# <p align="justify">O resultado obtido indica que existem 28.976 valores acima do limite superior para a variável 'new_vaccinations'. Temos um coeficiente de assimetria de 17.52, isso indica uma distribuição altamente assimétrica à direita, ou seja, existem muitos valores extremamente altos puxando a média para esse lado. Isso sugere que a maioria dos países têm baixas quantidades de vacinação e que poucos países possuem altas quantidades de vacinação.</p>
#
# <p align="justify">Utilizaremos a transformação logarítmica para reduzir a assimetria da distribuição e, assim, melhorar a análise. Abaixo, a verificação dos valores iguais a zero.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'new_vaccinations'
print(f"Quantidade de valores iguais a zero em 'new_vaccinations': {len(df_clean.loc[df_clean['new_vaccinations'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'new_vaccinations': 74343

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'new_vaccinations'
median_total_vaccinations = df_clean.loc[df_clean['new_vaccinations'] > 0, 'new_vaccinations'].median()
df_clean.loc[df_clean['new_vaccinations'] <= 0, 'new_vaccinations'] = median_total_vaccinations

# Aplicar a transformação logarítmica p/ a variável 'new_vaccinations'
df_clean['log_new_vaccinations'] = np.log(df_clean['new_vaccinations'])

# Plotar o boxplot da variável 'log_new_vaccinations'
df_clean[['log_new_vaccinations']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_new_vaccinations')
plt.show()

print('\n')

print(f'Acima do limite superior de 193100.24  ===>     ', (len(df_clean[df_clean.log_new_vaccinations > 193100.24])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_vaccinations > 193100.24]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 193100.24 ======> ', (len(df_clean[df_clean.log_new_vaccinations <= 193100.24])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_new_vaccinations <= 193100.24]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 193100.24  ===>      0 entradas (0.00%)
# Até o limite superior de 193100.24 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.9 Variável `population`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'population'
limite_superior = df_clean['population'].quantile(0.75) + 1.5 * (df_clean['population'].quantile(0.75) - df_clean['population'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'population'
limite_inferior = df_clean['population'].quantile(0.25) - 1.5 * (df_clean['population'].quantile(0.75) - df_clean['population'].quantile(0.25))

print(f'Limite superior de population: {limite_superior:.2f}')
print(f'Limite inferior de population: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'population'
df_clean.population.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 55924640.50 =====>  ', (len(df_clean[df_clean.population > 55924640.50])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.population > 55924640.50]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 55924640.50 ========> ', (len(df_clean[df_clean.population <= 55924640.50])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.population <= 55924640.50]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'population'
skewness = skew(df_clean['population'])
print("Coeficiente de assimetria (skewness) ========>    {:.2f}".format(skewness))
# Out:
# Limite superior de population: 55924640.50
# Limite inferior de population: -32958139.50
# Acima do limite superior de 55924640.50 =====>   29558 entradas (10.61%)
# Até o limite superior de 55924640.50 ========>  248965 entradas (89.39%)
# Coeficiente de assimetria (skewness) ========>    9.12

# %% [markdown]
# <br>
#
# <p align="justify">O coeficiente de assimetria (skewness) de 9.12 indica uma distribuição altamente assimétrica à direita, o que significa que há um número significativo de valores extremamente altos na variável 'population'. Além disso, cerca de 10,61% dos dados estão acima do limite superior, o que indica uma presença significativa de outliers nessa variável. Isso sugere que transformações de dados, como a escala logarítmica, podem ser necessárias para reduzir a influência desses valores extremos na análise.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'population'
print(f"Quantidade de valores iguais a zero em 'population': {len(df_clean.loc[df_clean['population'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'population': 0

# %%
# Aplicar a transformação logarítmica p/ a variável 'population'
df_clean['log_population'] = np.log(df_clean['population'])

# Plotar o boxplot da variável 'log_population'
df_clean[['log_population']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_population')
plt.show()

print('\n')

print(f'Acima do limite superior de 55924640.50 ===>      ', (len(df_clean[df_clean.log_population > 55924640.50])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_population > 55924640.50]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 55924640.50 ======> ', (len(df_clean[df_clean.log_population <= 55924640.50])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_population <= 55924640.50]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 55924640.50 ===>       0 entradas (0.00%)
# Até o limite superior de 55924640.50 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.10 Variável `population_density`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'population_density'
limite_superior = df_clean['population_density'].quantile(0.75) + 1.5 * (df_clean['population_density'].quantile(0.75) - df_clean['population_density'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'population_density'
limite_inferior = df_clean['population_density'].quantile(0.25) - 1.5 * (df_clean['population_density'].quantile(0.75) - df_clean['population_density'].quantile(0.25))

print(f'Limite superior de population_density: {limite_superior:.2f}')
print(f'Limite inferior de population_density: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'population_density'
df_clean.population_density.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 700.27 =====>  ', (len(df_clean[df_clean.population_density > 700.27])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.population_density > 700.27]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 700.27 ========> ', (len(df_clean[df_clean.population_density <= 700.27])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.population_density <= 700.27]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'population_density'
skewness = skew(df_clean['population_density'])
print("Coeficiente de assimetria (skewness) ===>    {:.2f}".format(skewness))
# Out:
# Limite superior de population_density: 700.27
# Limite inferior de population_density: -349.84
# Acima do limite superior de 700.27 =====>   14094 entradas (5.06%)
# Até o limite superior de 700.27 ========>  264429 entradas (94.94%)
# Coeficiente de assimetria (skewness) ===>    9.44

# %% [markdown]
# <br>
#
# <p align="justify">Com um coeficiente de assimetria de 9.45, a variável 'population_density' apresentou uma distribuição altamente assimétrica. O limite superior calculado para a variável é de 700.27, e cerca de 5% dos dados estão acima desse limite.</p>
#
# <p align="justify">Isso sugere que a maioria dos valores está concentrada abaixo do limite superior, e uma pequena parcela de valores extremos está puxando a média para cima. É importante avaliarmos a presença de valores iguais a zero entre os dados, e posteriormente, procedermos com a transformação logarítmica da coluna population_density.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'population_density'
print(f"Quantidade de valores iguais a zero em 'population_density': {len(df_clean.loc[df_clean['population_density'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'population_density': 1206

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'population_density'
median_population_density = df_clean.loc[df_clean['population_density'] > 0, 'population_density'].median()
df_clean.loc[df_clean['population_density'] <= 0, 'population_density'] = median_population_density

# Aplicar a transformação logarítmica p/ a variável 'population_density'
df_clean['log_population_density'] = np.log(df_clean['population_density'])

# Plotar o boxplot da variável 'log_population_density'
df_clean[['log_population_density']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_population_density')
plt.show()

print('\n')

print(f'Acima do limite superior de 700.27 ===>      ', (len(df_clean[df_clean.log_population_density > 700.27])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_population_density > 700.27]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 700.27 ======> ', (len(df_clean[df_clean.log_population_density <= 700.27])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_population_density <= 700.27]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 700.27 ===>       0 entradas (0.00%)
# Até o limite superior de 700.27 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.11 Variável `gdp_per_capita`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'gdp_per_capita'
limite_superior = df_clean['gdp_per_capita'].quantile(0.75) + 1.5 * (df_clean['gdp_per_capita'].quantile(0.75) - df_clean['gdp_per_capita'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'gdp_per_capita'
limite_inferior = df_clean['gdp_per_capita'].quantile(0.25) - 1.5 * (df_clean['gdp_per_capita'].quantile(0.75) - df_clean['gdp_per_capita'].quantile(0.25))

print(f'Limite superior de population: {limite_superior:.2f}')
print(f'Limite inferior de population: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'gdp_per_capita'
df_clean.gdp_per_capita.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 53497.53 ====>  ', (len(df_clean[df_clean.gdp_per_capita > 53497.53])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.gdp_per_capita > 53497.53]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 53497.53 =======> ', (len(df_clean[df_clean.gdp_per_capita <= 53497.53])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.gdp_per_capita <= 53497.53]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'gdp_per_capita'
skewness = skew(df_clean['gdp_per_capita'])
print("Coeficiente de assimetria (skewness) ====>    {:.2f}".format(skewness))
# Out:
# Limite superior de population: 53497.53
# Limite inferior de population: -23417.53
# Acima do limite superior de 53497.53 ====>   16109 entradas (5.78%)
# Até o limite superior de 53497.53 =======>  262414 entradas (94.22%)
# Coeficiente de assimetria (skewness) ====>    2.21

# %% [markdown]
# <br>
#
# <p align="justify">O coeficiente de assimetria da variável 'gdp_per_capita' é positivo (2.21), o que indica uma assimetria à direita (a cauda da distribuição se estende mais para o lado direito). Além disso, apenas 5,78% dos dados estão acima do limite superior. Em termos práticos, isso significa que a maioria dos países tem um PIB per capita abaixo de 53.497,53, mas existem alguns países com um PIB per capita muito alto. Nesse caso, vamos proceder com a transformação logarítmica para tornar a distribuição mais simétrica e reduzir o impacto desses valores extremos na análise.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'gdp_per_capita'
print(f"Quantidade de valores iguais a zero em 'gdp_per_capita': {len(df_clean.loc[df_clean['gdp_per_capita'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'gdp_per_capita': 0

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'gdp_per_capita'
median_gdp_per_capita = df_clean.loc[df_clean['gdp_per_capita'] > 0, 'gdp_per_capita'].median()
df_clean.loc[df_clean['gdp_per_capita'] <= 0, 'gdp_per_capita'] = median_gdp_per_capita

# Aplicar a transformação logarítmica p/ a variável 'gdp_per_capita'
df_clean['log_gdp_per_capita'] = np.log(df_clean['gdp_per_capita'])

# Plotar o boxplot da variável 'log_gdp_per_capita'
df_clean[['log_gdp_per_capita']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_gdp_per_capita')
plt.show()

print('\n')

print(f'Acima do limite superior de 53497.53 ===>      ', (len(df_clean[df_clean.log_gdp_per_capita > 53497.53])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_gdp_per_capita > 53497.53]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 53497.53 ======> ', (len(df_clean[df_clean.log_gdp_per_capita <= 53497.53])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_gdp_per_capita <= 53497.53]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 53497.53 ===>       0 entradas (0.00%)
# Até o limite superior de 53497.53 ======>  278523 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.12 Variável `reproduction_rate`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'reproduction_rate'
limite_superior = df_clean['reproduction_rate'].quantile(0.75) + 1.5 * (df_clean['reproduction_rate'].quantile(0.75) - df_clean['reproduction_rate'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'reproduction_rate'
limite_inferior = df_clean['reproduction_rate'].quantile(0.25) - 1.5 * (df_clean['reproduction_rate'].quantile(0.75) - df_clean['reproduction_rate'].quantile(0.25))

print(f'Limite superior de reproduction_rate: {limite_superior:.2f}')
print(f'Limite inferior de reproduction_rate: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'reproduction_rate'
df_clean.reproduction_rate.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 1.43 =======>  ', (len(df_clean[df_clean.reproduction_rate > 1.43])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.reproduction_rate > 1.43]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 1.43 ==========> ', (len(df_clean[df_clean.reproduction_rate <= 1.43])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.reproduction_rate <= 1.43]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'gdp_per_capita'
skewness = skew(df_clean['reproduction_rate'])
print("Coeficiente de assimetria (skewness) ===>    {:.2f}".format(skewness))
# Out:
# Limite superior de reproduction_rate: 1.43
# Limite inferior de reproduction_rate: 0.43
# Acima do limite superior de 1.43 =======>   11324 entradas (4.07%)
# Até o limite superior de 1.43 ==========>  267199 entradas (95.93%)
# Coeficiente de assimetria (skewness) ===>    0.17

# %% [markdown]
# <br>
#
# <p align="justify">O coeficiente de assimetria da variável 'reproduction_rate' é positivo (0.17), o que indica uma assimetria à direita (a cauda da distribuição se estende mais para o lado direito). Além disso, 11.324 (4,07%) dos dados estão acima do limite superior. Nesse caso, vamos proceder com a transformação logarítmica para tornar a distribuição mais simétrica e reduzir o impacto desses valores extremos na análise.</p>

# %%
# Verificar a quantidade de valores iguais a zero na coluna 'reproduction_rate'
print(f"Quantidade de valores iguais a zero em 'reproduction_rate': {len(df_clean.loc[df_clean['reproduction_rate'] == 0])}")
# Out:
# Quantidade de valores iguais a zero em 'reproduction_rate': 3623

# %%
# Substituir os valores iguais a zero pela mediana da coluna 'reproduction_rate'
median_reproduction_rate = df_clean.loc[df_clean['reproduction_rate'] > 0, 'reproduction_rate'].median()
df_clean.loc[df_clean['reproduction_rate'] <= 0, 'reproduction_rate'] = median_reproduction_rate

# Aplicar a transformação logarítmica p/ a variável 'reproduction_rate'
df_clean['log_reproduction_rate'] = np.log(df_clean['reproduction_rate'])

# Plotar o boxplot da variável 'log_reproduction_rate'
df_clean[['log_reproduction_rate']].boxplot(vert=False, figsize=(10, 3))
plt.title('Boxplot da variável log_reproduction_rate')
plt.show()

print('\n')

print(f'Acima do limite superior de 1.43 ===>      ', (len(df_clean[df_clean.log_reproduction_rate > 2.00])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_reproduction_rate > 1.43]) / df_clean.shape[0])*100))

print(f'Até o limite superior de 1.43 ======> ', (len(df_clean[df_clean.log_reproduction_rate <= 1.43])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.log_reproduction_rate <= 1.43]) / df_clean.shape[0])*100))
# Out:
# Acima do limite superior de 1.43 ===>       0 entradas (0.00%)
# Até o limite superior de 1.43 ======>  278512 entradas (100.00%)

# %% [markdown]
# <br>
#
# ###**3.6.13 Variável `stringency_index`**

# %%
# Cálculo do Limite Superior -  p/ a variável 'stringency_index'
limite_superior = df_clean['stringency_index'].quantile(0.75) + 1.5 * (df_clean['stringency_index'].quantile(0.75) - df_clean['stringency_index'].quantile(0.25))

# Cálculo do Limite Inferior -  p/ a variável 'stringency_index'
limite_inferior = df_clean['stringency_index'].quantile(0.25) - 1.5 * (df_clean['stringency_index'].quantile(0.75) - df_clean['stringency_index'].quantile(0.25))

print(f'Limite superior de population: {limite_superior:.2f}')
print(f'Limite inferior de population: {limite_inferior:.2f}\n')

# Plotar o boxplot da variável 'stringency_index'
df_clean.stringency_index.plot(kind="box", vert=False, figsize=(15, 3), color = 'blue')
plt.show()
print('\n')

# Visualizar o total de entradas em (%) acima do limite superior  
print(f'Acima do limite superior de 84.73 ======>   ', (len(df_clean[df_clean.stringency_index > 84.73])), 'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.stringency_index > 84.73]) / df_clean.shape[0])*100))

# Visualizar o total de entradas em (%) até o limite superior
print(f'Até o limite superior de 84.73 =========> ', (len(df_clean[df_clean.stringency_index <= 84.73])),'entradas',
      "({:.2f}%)".format((len(df_clean[df_clean.stringency_index <= 84.73]) / df_clean.shape[0])*100))

# Calcular o coeficiente de assimetria (skewness) da variável 'stringency_index'
skewness = skew(df_clean['stringency_index'])
print("Coeficiente de assimetria (skewness) ===>    {:.2f}".format(skewness))
# Out:
# Limite superior de population: 84.73
# Limite inferior de population: -0.47
# Acima do limite superior de 84.73 ======>    8065 entradas (2.90%)
# Até o limite superior de 84.73 =========>  270458 entradas (97.10%)
# Coeficiente de assimetria (skewness) ===>    0.21

# %% [markdown]
# <br>
#
# ##**3.7 Covid-19 Casos e óbitos**

# %% [markdown]
# <p align="justify">Para fins didáticos, vamos considerar o total de casos até a data de 20/03/2023, pois como o arquivo "owid-covid-data.csv" é atualizado diariamente, podem existir atrasos ou falhas na inclusão dos novos registros de casos em alguns países, porque não existe uma padronização tecnológica para a divulgação.</p>

# %% [markdown]
# <br>
#
# ###**3.7.1 Covid-19 >> Casos confirmados**

# %% [markdown]
# <p align="justify">No período selecionado de 20 de março de 2023, verificamos no dataset que os 5 países com a maior quantidade de casos confirmados para a Covid-19 foram: Estados Unidos (102 milhões de casos), China (99 milhões), Índia (44 milhões), França (38,6 milhões) e Alemanha (38,3 milhões de casos), conforme código e ouput abaixo:</p>

# %%
# Total de casos confirmados
df_clean.loc[df_clean.date == '2023-03-20'].sort_values(by="total_cases", ascending=False).head(10)
# Out:
#        iso_code      continent        location       date  total_cases  \
# 282554      USA  North America   United States 2023-03-20  102544598.0
# 53190       CHN           Asia           China 2023-03-20   99229371.0
# 120464      IND           Asia           India 2023-03-20   44696338.0
# 90941       FRA         Europe          France 2023-03-20   38621921.0
# 98034       DEU         Europe         Germany 2023-03-20   38301169.0
# 36640       BRA  South America          Brazil 2023-03-20   37204677.0
# 131105      JPN           Asia           Japan 2023-03-20   33374303.0
# 250657      KOR           Asia     South Korea 2023-03-20   30702960.0
# 128740      ITA         Europe           Italy 2023-03-20   25659646.0
# 281372      GBR         Europe  United Kingdom 2023-03-20   24271342.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 282554      200.0           18087.571     1114970.0         9.0
# ...

# %% [markdown]
# <br>
#
# <p align="justify">A seguir, vamos plotar o gráfico de linhas para melhor visualização da evolução do total de casos de Covid-19 entre os 5 países com os maiores índices apresentados.</p>

# %%
# Selecionar os dados de location, date e total_cases
df_cases = df_clean[['location', 'date', 'total_cases']]

# Agrupar os dados pela data e pela localização, somando o número total de casos em cada grupo
df_cases_grouped = df_cases.groupby(['date', 'location']).sum()

# Selecionar os dados apenas para as localizações que deseja plotar no gráfico de linhas
locations = ['United States', 'China', 'India', 'France', 'Germany']
df_cases_top5 = df_cases_grouped.loc[df_cases_grouped.index.get_level_values('location').isin(locations)]

# Pivotar o dataframe agrupado para que as localizações se tornem as colunas
df_cases_pivoted = df_cases_top5.pivot_table(index='date', columns='location', values='total_cases')

# Plotar o gráfico de linhas
fig, ax = plt.subplots(figsize=(10, 5))
for location in locations:
    ax.plot(df_cases_pivoted.index, df_cases_pivoted[location], label=location)
ax.set_title('Evolução do Total de Casos de Covid-19 (Países com Mais Casos) até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Quantidade Total de Casos')
ax.legend()

# Ajustar os limites do eixo x para remover a linha de plotagem no final do gráfico
ax.set_xlim(pd.Timestamp('2020-01-01'), pd.Timestamp('2023-03-20'))

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <br>
#
# <p align="justify">Um dos motivos que levaram os países a desenvolverem rapidamente a vacina contra a Covid-19, foi a preocupação com a progressão do número total de casos e mortes no mundo. Uma das melhores formas de visualizarmos a evolução ao longo do tempo, é o gráfico de linhas. Por isso, vamos plotar um gráfico de linha para demonstrar e evolução de casos no mundo.</p>
#
# <br>
# <center>
#
# | País           | Total de casos   |
# |----------------|-----------------:|
# | Estados Unidos |  102.544.598     |
# | China          |   99.229.371     |
# | Índia          |   44.696.338     |
# | França         |   38.621.921     |
# | Alemanha       |   38.301.169     |
# | Brasil         |   37.204.677     |
# | Japão          |   33.374.303     |
# | Coreia do Sul  |   30.702.960     |
# | Itália         |   25.659.646     |
# | Inglaterra     |   24.271.342     |
#
# </center><br>

# %% [markdown]
# <br>
#
# <p align="justify">A partir da seleção da variáveis 'date', 'location' e 'total_cases', foi possível plotar um gráfico de linhas, demonstrando a evolução do total de casos de Covid-19, confirmados no mundo, até a data de 20/03/2023.

# %%
# Selecionar os dados de location, date e total_cases
df_cases = df_clean[['location', 'date', 'total_cases']]

# Filtrar os dados para incluir apenas as datas mais recentes
df_cases_recent = df_cases[df_cases['date'] >= '2020-01-01']

# Agrupar os dados pela data, somando o número total de casos em cada grupo
df_cases_grouped = df_cases_recent.groupby('date').sum()

# Plotar o gráfico de linhas
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df_cases_grouped.index, df_cases_grouped['total_cases'], label='Total de Casos', color='brown')
ax.set_title('Evolução do Total de Casos de Covid-19 no Mundo até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Quantidade de Casos')

# Ajustar os limites do eixo x para remover a linha de plotagem no final do gráfico
ax.set_xlim([df_cases_grouped.index[0], df_cases_grouped.index[-10]])

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <br>
#
# ###**3.7.2 Covid-19 >> Mortes confirmadas**

# %% [markdown]
# <p align="justify">Dando sequência a nossa análise exploratória de dados, vamos localizar a data mais recente em que houve novos casos de mortes registrados no dataset por Covid-19 no Mundo, conforme código e output abaixo:</p>

# %%
# Usar o método max() para localizar a data mais recente de novos casos
data_atual = df_clean.loc[df_clean['new_deaths'] > 0, 'date'].max()
print('Data mais recente com novos casos de mortes: ', data_atual)
# Out:
# Data mais recente com novos casos de mortes:  2023-03-30 00:00:00

# %% [markdown]
# <br>
#
# <p align="justify">Conforme observado acima, a data de 30/03/2023 corresponde ao período mais recente em que houve um registro no conjunto de dados analisado sobre mortalidade em decorrência da Covid-19. Em sequência, vamos apurar quais são os 5 países líderes em casos de mortes confirmados até a data de 20/03/2023, conforme código e output abaixo:</p>

# %%
# Total de mortes confirmadas
df_clean.loc[df_clean.date == '2023-03-20'].sort_values(by="total_deaths", ascending=False).head(5)
# Out:
#        iso_code      continent       location       date  total_cases  \
# 282554      USA  North America  United States 2023-03-20  102544598.0
# 36640       BRA  South America         Brazil 2023-03-20   37204677.0
# 120464      IND           Asia          India 2023-03-20   44696338.0
# 219988      RUS         Europe         Russia 2023-03-20   22516509.0
# 168527      MEX  North America         Mexico 2023-03-20    7515754.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 282554      200.0           18087.571     1114970.0         9.0
# 36640     59163.0            8451.857      699917.0       283.0
# 120464      918.0             771.714      530806.0         4.0
# 219988    10310.0           11878.286      396865.0        31.0
# 168527      772.0            2497.857      333398.0        18.0
#
#         new_deaths_smoothed  ...  log_total_deaths  log_new_deaths  \
# 282554              248.714  ...         13.924338        2.197225
# ...

# %% [markdown]
# <br>
#
# <p align="justify">Até o período selecionado de 20 de março de 2023, verificamos no dataset que os 5 países com maior quantidade de mortes por Covid-19 foram: Estados Unidos (1,114 milhões de mortes), Brasil (699 mil), Índia (530 mil), Rússia (396 mil) e México (333 mil).</p><br>
# <center>
#
# | País           | Total de mortes  |
# |----------------|-----------------:|
# | Estados Unidos |  1.114.970       |
# | Brasil         |   699.917        |
# | Índia          |   530.806        |
# | Rússia         |   396.865        |
# | México         |   333.398        |
#
# </center><br>
#
# <p align="justify">A seguir, vamos plotar o gráfico de barras para uma melhor visualização para os 5 países com a maior quantidade de mortes registradas no conjunto de dados examinado.</p>

# %%
# Selecionar os dados para o dia 20 de março de 2023 e os 5 países com mais mortes
df_top5 = df_clean.loc[df_clean.date == '2023-03-20'].sort_values(by="total_deaths", ascending=False).head(5)

# Criar o objeto fig, ax
fig, ax = plt.subplots(figsize=(7, 4))

# Plotar o gráfico de barras
ax.bar(df_top5['location'], df_top5['total_deaths'], color='brown')
ax.set_title('Mortes por Covid-19 até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Quantidade de Mortes (em milhões)')

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <br>
#
# ###**3.7.3 Covid-19 >> Testes confirmados**

# %% [markdown]
# <p align="justify">Até o período selecionado de 20 de março de 2023, verificamos no dataset que os 5 países com maior quantidade de testes realizados para a Covid-19 no mundo eram: Estados Unidos (1,3 bilhões de testes), Índia (1,1 bilhões), China (934 milhões), Reino Unido (599 milhões) e Brasil (447 milhões de testes).</p>

# %%
# Total de testes
df_clean[['location'] + cols_numericas].loc[df_clean.date == '2023-03-20'].sort_values(by="total_tests", ascending=False).head(5)
# Out:
#              location  total_cases  new_cases  total_deaths  new_deaths  \
# 53190           China   99229371.0     4867.0      120775.0        43.0
# 282554  United States  102544598.0      200.0     1114970.0         9.0
# 120464          India   44696338.0      918.0      530806.0         4.0
# 98034         Germany   38301169.0      652.0      170364.0         8.0
# 90941          France   38621921.0     5459.0      161650.0         2.0
#
#          total_tests     new_tests  population_density  reproduction_rate  \
# 53190   1.500979e+09  1.148954e+06             147.674           0.377648
# 282554  1.229627e+09  1.246702e+06              35.608           0.819551
# 120464  9.423729e+08  7.119469e+05             450.419           0.935396
# 98034   4.519475e+08  3.868054e+05             237.016           0.786229
# 90941   4.463266e+08  3.893963e+05             122.578           0.754386
#
#           population  gdp_per_capita  total_vaccinations  new_vaccinations  \
# ...

# %%
# Selecionar os dados para o dia 20 de março de 2023 e os 5 países com mais testes realizados
df_top5 = df_clean.loc[df_clean.date == '2023-03-20'].sort_values(by="total_tests", ascending=False).head(5)

# Criar o objeto fig, ax
fig, ax = plt.subplots(figsize=(7, 4))

# Plotar o gráfico de barras
ax.bar(df_top5['location'], df_top5['total_tests'], color='brown')
ax.set_title('Testes para Covid-19 até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Quantidade de Testes (em milhões)')

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <p align="justify">A seguir, vamos apresentar no dataset quais foram os 5 países com maior quantidade de doses de vacina contra a Covid-19 no mundo: China e Índia com 2,2 bilhões de doses ministradas, Estados Unidos (673 milhões), Japão (383 milhões) e Indonésia (323 milhões).</p>

# %%
# Total de vacinações
df_clean[['location'] + cols_numericas].loc[df_clean.date == '2023-03-20'].sort_values(by="total_vaccinations", ascending=False).head(5)
# Out:
#              location  total_cases  new_cases  total_deaths  new_deaths  \
# 53190           China   99229371.0     4867.0      120775.0        43.0
# 120464          India   44696338.0      918.0      530806.0         4.0
# 282554  United States  102544598.0      200.0     1114970.0         9.0
# 131105          Japan   33374303.0     5938.0       73511.0        34.0
# 121647      Indonesia    6741588.0      234.0      160975.0         4.0
#
#          total_tests     new_tests  population_density  reproduction_rate  \
# 53190   1.500979e+09  1.148954e+06             147.674           0.377648
# 120464  9.423729e+08  7.119469e+05             450.419           0.935396
# 282554  1.229627e+09  1.246702e+06              35.608           0.819551
# 131105  4.385580e+08  3.090991e+05             347.778           0.754673
# 121647  1.221304e+08  2.047035e+05             145.725           0.943299
#
#           population  gdp_per_capita  total_vaccinations  new_vaccinations  \
# ...

# %%
# Selecionar os dados para o dia 20 de março de 2023 e os 5 países com mais vacinações realizadas
df_top5 = df_clean.loc[df_clean.date == '2023-03-20'].sort_values(by="total_vaccinations", ascending=False).head(5)

# Criar o objeto fig, ax
fig, ax = plt.subplots(figsize=(7, 4))

# Plotar o gráfico de barras
ax.bar(df_top5['location'], df_top5['total_vaccinations'], color='brown')
ax.set_title('Vacinações para Covid-19 até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Quantidade de Vacinações (em milhões)')

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <br>
#
# <p align="justify">Em sequência, vamos construir um gráfico do tipo de barras para apresentar a velocidade média de disseminação do vírus no mundo, permitindo comparar as diferentes velocidades e identificar aquelas que apresentam uma maior velocidade de disseminação.</p>
#
# <p align="justify">A velocidade de disseminação do vírus em cada região é calculada através da multiplicação da taxa de crescimento diário dos casos confirmados pela taxa de reprodução básica (R0) do vírus no mundo.</p>
#
# <p align="justify">Pelo gráfico plotado, podemos inferir que a Austrália foi o país que apresentou a maior velocidade de disseminação do vírus. É interessante observar que países como os Estados Unidos e a Índia, que estiveram posicionados entre os 3 países com maior número de casos e mortes não apresentam a maior velocidade de disseminação do vírus, ou seja, não é apenas o número absoluto de casos e mortes que determina a velocidade de disseminação do vírus, mas sim a taxa de crescimento diário dos casos confirmados e o valor de (R0) de reprodução em cada região.</p>
#
# <p align="justify">Assim, embora os Estados Unidos sejam o país com o maior número absoluto de casos e mortes confirmados, sua velocidade de disseminação do vírus pode não ser a mais alta devido à variação da taxa de crescimento diário dos casos confirmados e do valor de (R0) em outras regiões do mundo.</p>

# %%
import warnings
warnings.filterwarnings('ignore')

# Selecionar as colunas relevantes do conjunto de dados
df_clean = df_clean[['date', 'location', 'new_cases', 'new_deaths', 'reproduction_rate']].copy()

# Selecionar dados até a data de 2023-03-20
df_clean = df_clean[df_clean['date'] <= '2023-03-20']

# Calcular a taxa de crescimento diário dos casos confirmados
df_clean.loc[:, 'daily_cases_growth_rate'] = df_clean.groupby('location')['new_cases'].pct_change().fillna(0)

# Calcular a taxa de reprodução básica (R0)
df_clean.loc[:, 'reproduction_rate'] = df_clean.groupby('location')['reproduction_rate'].fillna(method='ffill')

# Calcular a velocidade de disseminação do vírus global
df_clean.loc[:, 'velocity'] = df_clean['reproduction_rate'] * df_clean['daily_cases_growth_rate']

# Agrupar os dados globais e calcular a velocidade média de disseminação do vírus
df_global = df_clean.groupby('location')[['velocity']].mean().reset_index()

# Ordenar os países de acordo com a velocidade média de disseminação do vírus
df_global = df_global.sort_values(by='velocity', ascending=False)

# Mostrar os 10 países com maior disseminação do vírus
df_global_top10 = df_global.head(10)

# Gerar um gráfico de barras horizontais para visualizar a velocidade média de disseminação do vírus global
plt.figure(figsize=(10, 4))
plt.barh(df_global_top10['location'], df_global_top10['velocity'], color='brown')
plt.xlabel('Velocidade de disseminação')
plt.title('Velocidade média de disseminação do vírus no Mundo até 20/03/2023 (Top 10 Países)')

# Ajustar o tamanho da fonte dos rótulos do eixo y
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# <br>
#
# <p align="justify">Buscando compreender melhor como é a relação entre as políticas de mitigação e as taxas de casos e mortes em diferentes países, utilizaremos a variável 'stringency_index', que informa a severidade das medidas governamentais adotadas em relação à pandemia da Covid-19 no mundo.</p>
#
# <p align="justify">Ele é calculado a partir de nove indicadores, como por exemplo, o fechamento de escolas, cancelamento de eventos públicos, restrições de viagens, entre outros. Quanto maior o índice, maior é a severidade das medidas adotadas pelo governo do país em questão.</p>

# %%
# Exibir o valor mínimo e máximo do índice 
df_clean['stringency_index'].describe()
# Out:
# count    299028.000000
# mean         43.837827
# std          27.972600
# min           0.000000
# 25%          30.690000
# 50%          42.775017
# 75%          53.650000
# max         797.585551
# Name: stringency_index, dtype: float64

# %% [markdown]
# <br>
#
# <p align="justify">A seguir, vamos apresentar no dataset quais foram os 10 países que apresentaram o maior índice de severidade governamental, conforme código e output abaixo:</p>

# %%
# Índice de Severidade Governamental
df_clean.loc[df.date == '2023-03-20', ['location', 'stringency_index']].sort_values(by="stringency_index", ascending=False).head(5)
# Out:
#          location  stringency_index
# 172073     Monaco         68.095261
# 168527     Mexico         65.916791
# 36640      Brazil         56.316120
# 154346      Macao         55.648561
# 241200  Singapore         50.921435

# %%
# Selecionar os dados para o dia 20 de março de 2023 e os 5 países com maiores índices de severidade governamental
df_top5 = df_clean.loc[df.date == '2023-03-20', ['location', 'stringency_index']].sort_values(by="stringency_index", ascending=False).head(5)

# Criar o objeto fig, ax
fig, ax = plt.subplots(figsize=(7, 4))

# Plotar o gráfico de barras
ax.bar(df_top5['location'], df_top5['stringency_index'], color='brown')
ax.set_title('Índice de Severidade para Covid-19 até 20/03/2023')
ax.set_xlabel('')
ax.set_ylabel('Escala de 0 a 100')

# Definir formato dos rótulos do eixo y
ax.ticklabel_format(style='plain', axis='y')

# Exibir o gráfico
plt.show()

# %% [markdown]
# <br>
#
# <p align="justify">Para fins de comparação, vamos demonstrar o Índice de Severidade médio dos Estados Unidos, Brasil, Índia, Rússia e México, que apresentaram a maior quantidade de mortes registradas por Covid-19 para o mesmo período, conforme código abaixo:</p>

# %%
# Listar países
paises = ['United States', 'Brazil', 'India', 'Russia', 'Mexico']

# Filtrar o DataFrame por location
df_paises = df_clean.loc[df_clean['location'].isin(paises)]

# Agrupar por país e calcular a média
media_stringency = df_paises.groupby('location')['stringency_index'].mean()

# Mostrar a média por país
print(media_stringency)
# Out:
# location
# Brazil           48.721891
# India            54.309961
# Mexico           46.364950
# Russia           42.265661
# United States    45.747937
# Name: stringency_index, dtype: float64

# %% [markdown]
# <br>
#
# <p align="justify">Podemos inferir que a média do índice entre os 5 países com  as maiores restrições governamentais foi de 91,80, enquanto que a média dos países com a maior quantidade de mortes registradas foi de 48,94.</p>

# %%
fig, ax = plt.subplots(figsize=(7, 4))

ax.bar(media_stringency.index, media_stringency.values, color='brown')
ax.set_xticklabels(media_stringency.index, rotation=360, ha='center')
ax.set_ylim(0, 100)
ax.set_xlabel('')
ax.set_ylabel('Índice de Severidade')
ax.set_title('Média do Índice de Severidade por País até 20/03/2023')

plt.show()

# %% [markdown]
# <br>
#
# ## **4. Análise Exploratória dos Dados - Covid-19 no Brasil**

# %% [markdown]
# <p align="justify">Até o presente momento da análise explorátória, tivemos uma visão sistêmica da progressão epidemiológica do Covid-19 no mundo. Entretanto, vamos agora, analisar os acontecimentos no Brasil.</p>
#
# <p align="justify">Como queremos visualizar somente os dados do Brasil, vamos gerar uma cópia do DataFrame 'df_clean', apenas para o país Brasil, conforme código abaixo:</p>

# %%
# Selecionar apenas as linhas correspondentes ao Brasil
df_brazil = df.loc[df['location'] == 'Brazil'].copy()

# %% [markdown]
# ### **4.1 Analisando o início da trajetória do Covid-19 no Brasil**

# %% [markdown]
# <p align="justify">Conforme relatamos na Introdução deste projeto, segundo fontes oficiais do Ministério da Saúde, o primeiro caso de Covid-19 no Brasil, foi confirmado em 26 de fevereiro de 2020 e o primeiro registro de óbito ocorreu em 17 de março de 2020.</p>
#
# <p align="justify">Em consulta ao nosso conjunto de dados, verificamos que o primeiro caso registrado no Brasil ocorreu em 27 de fevereiro de 2020. Já o primeiro óbito ocorreu em 19 de março de 2023, ou seja, 20 dias após o primeiro caso registrado.
#
# <p align="justify">Pode haver divergências entre as informações oficiais e os dados apresentados no dataset devido a várias razões, como diferenças na coleta de dados, atualização de informações e atrasos no registro de casos. Além disso, pode haver diferenças na forma como as mortes são contabilizadas e reportadas pelas autoridades em relação às fontes de dados usadas em conjuntos de dados. É importante levar em consideração essas possíveis diferenças ao interpretar os dados e informações relacionados ao COVID-19.</p>

# %%
# Identificar a data de registro do primeiro caso de Covid-19 no Brasil
df_brazil.loc[df_brazil['new_cases'] != 0.0].head(1)
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 35523      BRA  South America   Brazil  2020-02-27          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 35523               0.143           NaN         0.0                  0.0  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 35523          17.9                     NaN                         2.2
#
#        life_expectancy  human_development_index   population  \
# 35523            75.88                    0.765  215313504.0
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 35523                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 35523               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
# Identificar a data de registro do primeiro óbito por Covid-19 no Brasil
df_brazil.loc[df_brazil['new_deaths'] != 0.0].head(1)
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 35544      BRA  South America   Brazil  2020-03-19        291.0       57.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 35544              36.714           1.0         1.0                0.143  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 35544          17.9                     NaN                         2.2
#
#        life_expectancy  human_development_index   population  \
# 35544            75.88                    0.765  215313504.0
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 35544                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 35544               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
# definir a data mais recente dos dados
data_atual = pd.to_datetime(df_brazil['date']).max().strftime('%Y-%m-%d')

# selecionar apenas os dados até a data mais recente
#df_brazil = df_brazil.loc[df_brazil['date'] <= data_atual]

# criar uma lista com os dias desde o início dos dados
dias = list(range(len(df_brazil)))

# extrair os totais de casos e mortes
total_cases = df_brazil['total_cases']
total_deaths = df_brazil['total_deaths']

# criar uma figura com quatro subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))

# plotar o gráfico de casos em escala linear e logarítmica
ax1.set_title('Casos no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.plot(dias, total_cases)

ax2.set_title('Casos no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(dias, total_cases)

# plotar o gráfico de mortes em escala linear e logarítmica
ax3.set_title('Mortes no Brasil')
ax3.set_xlabel('Dias')
ax3.set_ylabel('Mortes')
ax3.plot(dias, total_deaths)

ax4.set_title('Mortes no Brasil (Escala logarítmica)')
ax4.set_xlabel('Dias')
ax4.set_ylabel('Mortes')
ax4.set_yscale('log')
ax4.plot(dias, total_deaths)

plt.tight_layout()
plt.show()

# %% [markdown]
# <br>
#
# ### **5. Conclusões**

# %% [markdown]
# ><p align="justify">A pandemia de Covid-19 tem impactado a maioria dos países no mundo, com uma tendência geral de crescimento de casos e mortes até meados de 2021, seguida de uma queda em alguns países devido ao aumento da vacinação e medidas de distanciamento social.</p>
#
# ><p align="justify">A taxa de mortalidade por Covid-19 variou significativamente entre os países. Algumas nações, como os Estados Unidos, Brasil e Índia, sofreram significativamente mais com a Covid-19 do que outras, como a Rússia e o México.</p>
#
# ><p align="justify">A vacinação se mostrou fundamental para reduzir o número de casos e mortes, com muitos países alcançando taxas de vacinação significativas em 2021.</p>
#
# ><p align="justify"> O índice de severidade governamental (stringency index) tem sido uma métrica importante para avaliar a eficácia das medidas tomadas pelos governos para conter a disseminação do vírus. Em geral, os países que adotaram medidas mais rigorosas de distanciamento social e restrições de viagem em resposta à pandemia, apresentaram melhores resultados na redução de casos e mortes.</p>
#
# ><p align="justify"> Em termos de projeções futuras, especialmente com o surgimento de novas variantes do vírus, é importante que todos os países continuem a implementar medidas de saúde pública para controlar a disseminação da doença.</p>
#
# ><p align="justify">Algumas sugestões para novos trabalhos nesse tema poderiam incluir uma análise mais detalhada da relação entre o índice de severidade governamental e o número de casos e mortes por Covid-19 em diferentes países, a fim de determinar a eficácia das medidas implementadas. Além disso, uma análise mais detalhada da evolução do índice de severidade governamental ao longo do tempo em diferentes países poderia ajudar a identificar padrões e tendências, e ajudar a determinar quais medidas foram mais eficazes em diferentes contextos.</p>
#
# ><p align="justify">Outras sugestões poderiam incluir uma análise da relação entre o índice de severidade governamental e outros fatores socioeconômicos, como o nível de desenvolvimento econômico, a desigualdade de renda e o acesso a serviços de saúde, a fim de determinar se esses fatores afetaram a capacidade dos países de implementar medidas eficazes de controle e contenção da pandemia.</p>

# %% [markdown]
# ###**Referências Bibliográficas**
#
# OLIVEIRA, Wanderson Kleber de et al . Como o Brasil pode deter a COVID-19. Epidemiol. Serv. Saúde,  Brasília ,  v. 29, n. 2,  e2020044,    2020 .   Disponível em <http://scielo.iec.gov.br/scielo.php?script=sci_arttext&pid=S1679-49742020000200002&lng=pt&nrm=iso>. acessos em  16  mar.  2023.  Epub 24-Abr-2020.  http://dx.doi.org/10.5123/s1679-49742020000200023.
#
# OUR WORLD IN DATA. Coronavirus Pandemic (COVID-19). Disponível em: https://ourworldindata.org/coronavirus [ Links ]
